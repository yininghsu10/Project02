# %%
from pymongo import MongoClient
import pandas as pd
#連接MongoDB
client = MongoClient("mongodb+srv://test:test@cluster0.j7nzi.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
#指定資料庫
db = client.costco
#指定資料表
col=db.FB_pythons
#直接從MongoDB查詢
post=col.distinct("FB內文")
# data=pd.DataFrame({"FB內文":post})
# print(data)
print(post)
#--------------------------------------------
#將FB內文進行斷詞
import jieba
word=[]
for i in post:
    a=jieba.cut(i)    
    word+=a
print(word)   
#--------------------------------------------
#統計每個字串出現次數
#把每個字串當成key去計算出現的次數(當成值)
dic_w={}
#判斷KEY(ele)是否在dic_w{}裡面
for ele in word:
    #如果KEY(ele)不在dic_w{}裡面,如果KEY沒出現過，就新增一筆KEY並讓值從1開始
    if ele not in dic_w:
        dic_w[ele]=1
    #如果KEY重複出現，值(AKA次數)就+1
    else:
        dic_w[ele]+=1
print(dic_w)
#--------------------------------------------
#調整顯示方式
#因為dic是無序的，所以要用.items來排序呼叫
for ele in dic_w.items():
#     print(ele[0],ele[1])
    #兩個字以上的，才會出現
    if len(ele[0])>=2:
        num=list()
        word=list()
        #因為經過.items的關係，變成(0,1)=(前面,後面)
#         print(ele[0],ele[1])
#--------------------------------------------
#要排序次數
import operator
#itemgetter是指出現該函數內第幾個的意思(從0開始數)
#.itemgetter()從0開始會變成依筆畫排列
sort_w=sorted(dic_w.items(),key=operator.itemgetter(1),reverse=True)
for ele in sort_w:
    num=list()
    word=list()
    for i in range(len(sort_w)):
        a=sort_w.pop()
        num.append(a[1])
        word.append(a[0])    
df_extract=pd.DataFrame({'num':num,'word':word})
print(df_extract)
# Out:
# ['#勞動節愉快假日老梗快閃補貨兩串衛生紙跟風團友推薦起司餅乾一度找不到很著急問了工作人員（為了吃使命必達）總是買的比預期的多#今日…… 顯示更多', '#發問#DON萊賽爾單人涼被三件組有人買這嗎？有推或分享文嗎？', '#被隔離的物資朋友友情進貢一箱洋芋片讓我徹底當個沙發馬鈴薯然後這一箱冷泡咖啡第一次喝，還不錯可能我少見多怪，之前都是買超商咖啡沒喝過這種咖啡茶包包的咖啡 挺新奇的…… 顯示更多', '2022/5/2 PM15:25誰的衛生紙遺忘了，新莊店2樓-輪胎中心對面，推車放置區，因為自己有急事要先行離開，…… 顯示更多', 'CP值不錯的玩具，質感也很不錯附上行車紀錄影片', 'S&W DICED TOMATOES切塊番茄一箱8罐 $289我被架上的價錢給混淆了感謝網友提醒…… 顯示更多', '【繽紛蒜香鮭魚烤蝦仁】#氣炸料理適合料理新手或現代小廚房', '七位なめ茸非常日本道地的醃製金針菇口感脆脆甘口～老公小孩都很愛吃但夾的時候千萬記得要用乾湯匙筷子明明…… 顯示更多', '三天兩頭像在走灶咖的新發現,凱撒雞肉沙拉今天開始調漲了！昨天還在特價159-20今天從159漲到179', '上次買太多燕麥喝到過期，這次一箱就好（咖啡不錯，又回購的）', '下雨天扛了雨刷回家不過似乎沒有ML接頭可以想問問有沒有gla250裝過的版友可以告訴安裝方法…… 顯示更多', '今天看到一箱折價了100元，腦波的我搬了二箱回家喝', '優惠商品情報https://www.daybuy.tw/costco-36167Costco優惠通知，喜生冷凍洋蔥牛肉米漢堡，05/12前折價 100元', '先去全聯買了小包裝試喝怕踩雷，果然好喝不失望！', '冰萃濾袋咖啡一盒裡面40袋可以隨個人喜好調整冷萃的時間加牛
�碎黑巧克力雪糕(小孩的最)#伯爵紅茶杏仁脆片巧克力雪糕￼(特別伯爵茶清香)', '洗衣+烘乾，是梅雨時節婦女的夢幻逸品，想問問這台有人用過嗎？被吸引了，想跟老公討論一下', '看到版上的松露發霉慘案買了一些小盒子分裝冷凍起來希望他們可以好好的活久一點', '真的對好市多的水果沒信心了。昨天才買，今天一打開就是這付德行￼。想拿回去退一路上的油錢又划不來。￼', '社員分享台南也有顧低罷特賣，馬上跑去找，果然看到了攤位，可是草莓這種口味就是個雷者恆雷的難題，不是大地雷就是藥水味，很少有做的好吃的⋯⋯', '結帳後沒有馬上核對， 回到家才發現買 洋蔥 貝果 小姐結帳成 綜合 貝果 相差25塊', '藍色單吃最好吃，黃色會想挑著牛奶糖吃', '覺得肉質有點太韌，連我牙口這麼好都招架不住，炒過更明顯小孩也嫌棄，想請教買回去的人都做什麼料理，有推薦的前置作業嗎？謝謝（已嘗試太白粉抓醃）', '請問各位一下～這種燃油清潔劑優缺點，如～清潔力太強影響墊片或是塑膠製品等！或是～清潔力不夠如同虛有商品？', '請問有人用過這個嗎？線上限定的可以說說用過的感覺嗎？謝謝', '請問有人用過這款strivectin重返青春全能眼霜？好用嗎', '請問有人知道瑪利歐賽車的電池哪裡買得到', '請問有人買過這款，覺得有藥水味嗎？', '請問有使用惠而浦烤箱的版友有遇到過類似的狀況嗎？', '請問有切換保溫的好像是另一款嗎⋯⋯', '請問有沒有人買過這個款Glasslock玻璃微波碗，想請教不含蓋子時的高度多少？我從規格上只看到含蓋子一起時的高度是130mm.', '請問此樂高是標準的還是迷你的？', '請問瑪斯卡邦乳酪可以做什麼？求食譜。謝謝！', '請問這款科克蘭柴油車用油是否可使用一般汽油引擎上？因科克蘭另外2款缺貨很久…..', '赤玉干貝', '這個好吃又便宜..好多人買..', '這個摺疊桌實在是太棒了，力推', '這個有人用過嗎好用嗎', '這個禮拜滾筒洗衣機在特價請問有人可以分享使用經驗嗎￼￼', '這台有人用過嗎？評價如何？', '這批的加州蜜李很甜很好吃，很推薦！￼而且還折$30￼', '韓式牛腩大醬湯看很多會員買都說好吃於是乎我也跑去試吃一下果然不錯吃而且方便孩子在家自己煮…… 顯示更多', '驚! 這個一盒要$1439看了一下才16包，這樣一包就要80幾塊欸我的媽阿是我見識太少嗎，一包相當於一個便當而且才幾ml啊!! 小小一包一口都不夠塞吧一口100的東西真的有人吃得下去嗎…… 顯示更多']
# ['#', '勞動節', '愉快', '假日', '老梗快', '閃補貨', '兩串', '衛生紙', '跟', '風團友', '推薦', '起司餅', '乾', '一度', '找', '不到', '很著', '急問', '了', '工作', '人員', '（', '為', '了', '吃', '使命', '必達', '）', '總是', '買', '的', '比', '預期', '的', '多', '#', '今日', '…', '…', ' ', '顯示', '更', '多', '#', '發問', '#', 'DON', '萊賽爾', '單人涼', '被', '三件', '組', '有人', '買', '這嗎', '？', '有', '推', '或', '分享', '文', '嗎', '？', '#', '被', '隔', '離', '的', '物資', '朋友', '友情', '進貢', '一箱', '洋芋片', '讓', '我', '徹底', '當個', '沙發馬鈴', '薯然', '後', '這', '一箱', '冷泡', '咖啡', '第一次', '喝', '，', '還不錯', '可能', '我少見', '多怪', '，', '之前', '都', '是', '買', '超商', '咖啡', '沒', '喝過', '這種', '咖啡茶', '包包', '的', '咖啡', ' ', '挺', '新奇', '的', '…', '…', ' ', '顯示', '更', '多', '2022', '/', '5', '/', '2', ' ', 'PM15', ':', '25', '誰', '的', '衛生紙', '遺忘', '了', '，', '新莊店', '2', '樓', '-', '輪胎', '中心', '對面', '，', '推車', '放置', '區', '，', '因為', '自己', '有', '急事', '要', '先行', '離開', '，', '…', '…', ' ', '顯示', '更', '多', 'CP', '值不錯', '的', '玩具', '，', '質感', '也', '很', '不錯', '附', '上行', '車紀錄', '影片', 'S', '&', 'W', ' ', 'DICED', ' ', 'TOMATOES', '切塊', '番茄', '一箱', '8', '罐', ' ', '$', '289', '我', '被', '架上', '的', '價錢給', '混淆', '了', '感謝', '網友', '提醒', '…', '…', ' ', '顯示', '更', '多', '【', '繽紛', '蒜', '香', '鮭魚', '烤', '蝦仁', '】', '#', '氣炸', '料理', '適合', '料理', '新手', '或', '現代小', '廚房', '七位', 'な', 'め', '茸', '非常', '日本', '道', '地', '的', '醃', '製', '金', '針', '菇', '口感', '脆脆', '甘口', '～', '老公', '小孩', '都', '很', '愛吃', '但夾', '的', '時候', '千萬記', '得', '要', '用', '乾', '湯匙', '筷子', '明明', '…', '…', ' ', '顯示', '更', '多', '三天', '兩頭', '像', '在', '走', '灶', '咖', '的', '新', '發現', ',', '凱撒雞', '肉', '沙拉', '今天', '開始', '調漲', '了', '！', '昨天', '還在', '特價', '159', '-', '20', '今天', '從', '159', '漲到', '179', '上次', '買太多燕麥', '喝', '到', '過期', '，', '這次', '一箱', '就', '好', '（', '咖啡', '不錯', '，', '又', '回購', '的', '）', '下雨天', '扛', '了', '雨', '刷', '回家', '不過', '似乎', '沒有', 'ML', '接頭', '可以', '想', '問問', '有', '沒', '有', 'gla250', '裝過', '的', '版友', '可以', '告訴', '安裝', '方法', '…', '…', ' ', '顯示', '更', '多', '今天', '看到', '一箱', '折價', '了', '100', '元', '，', '腦波', '的', '我', '搬', '了', '二箱', '回家', '喝', '優惠', '商品', '情報', 'https', ':', '/', '/', 'www', '.', 'daybuy', '.', 'tw', '/', 'costco', '-', '36167Costco', '優惠', '通知', '，', '喜', '生冷', '凍洋蔥', '牛肉', '米漢堡', '，', '05', '/', '12', '前折價', ' ', '100', '元', '先去', '全聯買', '了', '小包', '裝試', '喝', '怕', '踩', '雷', '，', '果然', '好喝', '不', '失望', '！', '冰萃', '濾袋', '咖啡', '一盒', '裡面', '40', '袋', '可以', '隨個', '人', '喜好', '調整', '冷萃', '的', '時間', '加', '牛奶', '很', '好喝', '別人', '買', '雞', '胸肉', '是', '為', '了', '減肥', '我們', '買', '雞', '胸肉', '是', '為', '了', '做', '鹽', '酥', '雞', ' ', '前', '幾天', '在', '護照', '上', '看到', '有', '特價', '，', '就', '鎖定', '好', '這週', '要', '找', '天來', '買', '了', '勾豬', '肉', '在', 'costco', ' ', '賣', '的', '好', '便宜', '！', '！', '巧克力', '冰淇淋', '家庭', '號', '直接', '是', '半價', '唷', '！', '然後又有', '在', '試', '吃', '真是', '大家', '福音', '！', '！', '趕快', '去', '搶', '～', '雪糕', '6', '入', '$', '399', '冰淇淋', '6', '入', '$', '499', '#', '冰品', '北台', '中店', '有', '博士', '倫', 'lacelle', '的', '快', '閃', '活動', '了', '八款', '顏色', '任選', '12', '盒', '$', '2699', ' ', '還會', '多', '送', '一盒', '時間', '是', '4', '/', '29', '-', '5', '/', '8', '算下', '來', '是', '比', '外面', '買', '便宜', '我', '都', '戴', '他們', '家', '，', '韓國', '進口', '的', '品質', '都', '不錯', '…', '…', ' ', '顯示', '更', '多', '嘉義好', '市多', '停車場', '改進', '了', '耶', '，', '這樣', '就', '不用', '一直', '繞', '找', '車位', '了', '，', '讚', '！', '好', '一陣子', '沒去', '好市', '多', '了', '，', '結果', '今天', '一去', '就', '這一車', '⋯', '我', '的', '天', '啊', '～', '～', '今天', '看到', '漂亮', '的', '骨灰', '罈', '紅', '茶', '，', '買', '了', '蜜桃', '果茶', '女兒', '說', '小北', '一瓶', '要', '$', '18', '，', '好市', '多', '一箱', '$', '249', '，', '等', '於', '一瓶', '只要', '$', '10', '塊', '。', '買', '了', '好奇', '想問', '大家', '有買過', '這個', '嗎', '導熱', '效果', '好', '嗎', '主要', '煎肉', '用', '的', '或者', '大家', '買', '其他', '不錯', '的', '可以', '推薦', '我', ' ', '謝謝', '宅', '在家', ' ', '好市', '多線', '上', '購物', ' ', '整理', '房間', '小物', '好物', '推薦', ' ', 'sysmax', ' ', '16', '格', '抽屜', '盒', '$', '729', ' ', '*', '限線', '上', '購物', '*', ' ', '很', '好', '放', '很', '好', '收納', ' ', '附上', '整理', '完小', '物照', '內', '附', '16', '份格板', '可', '自由', '運用', '推推', '實測', '分享', '小時候', '我', '也 ...
# {'#': 10, '勞動節': 1, '愉快': 1, '假日': 1, '老梗快': 1, '閃補貨': 1, '兩串': 1, '衛生紙': 2, '跟': 4, '風團友': 1, '推薦': 5, '起司餅': 1, '乾': 2, '一度': 1, '找': 4, '不到': 1, '很著': 1, '急問': 1, '了': 28, '工作': 1, '人員': 1, '（': 3, '為': 3, '吃': 8, '使命': 1, '必達': 1, '）': 3, '總是': 1, '買': 19, '的': 71, '比': 4, '預期': 1, '多': 19, '今日': 1, '…': 27, ' ': 46, '顯示': 12, '更': 13, '發問': 1, 'DON': 1, '萊賽爾': 1, '單人涼': 1, '被': 4, '三件': 1, '組': 1, '有人': 13, '這嗎': 1, '？': 28, '有': 16, '推': 1, '或': 2, '分享': 4, '文': 1, '嗎': 24, '隔': 1, '離': 1, '物資': 1, '朋友': 2, '友情': 1, '進貢': 1, '一箱': 6, '洋芋片': 1, '讓': 1, '我': 19, '徹底': 1, '當個': 1, '沙發馬鈴': 1, '薯然': 1, '後': 3, '這': 1, '冷泡': 1, '咖啡': 5, '第一次': 1, '喝': 5, '，': 62, '還不錯': 1, '可能': 1, '我少見': 1, '多怪': 1, '之前': 1, '都': 10, '是': 18, '超商': 1, '沒': 6, '喝過': 1, '這種': 4, '咖啡茶': 1, '包包': 1, '挺': 1, '新奇': 1, '2022': 1, '/': 16, '5': 2, '2': 3, 'PM15': 1, ':': 4, '25': 2, '誰': 1, '遺忘': 1, '新莊店': 1, '樓': 1, '-': 8, '輪�
 7, '搶': 1, '雪糕': 3, '6': 2, '入': 2, '399': 1, '499': 1, '冰品': 1, '北台': 1, '中店': 1, '博士': 1, '倫': 1, 'lacelle': 1, '快': 1, '閃': 1, '活動': 1, '八款': 1, '顏色': 1, '任選': 1, '盒': 2, '2699': 1, '還會': 1, '送': 1, '4': 1, '29': 1, '算下': 1, '來': 7, '外面': 1, '戴': 1, '他們': 2, '家': 1, '韓國': 2, '進口': 1, '品質': 1, '嘉義好': 1, '市多': 1, '停車場': 1, '改進': 1, '耶': 1, '這樣': 7, '不用': 1, '一直': 1, '繞': 1, '車位': 1, '讚': 1, '一陣子': 1, '沒去': 1, '好市': 6, '結果': 1, '一去': 1, '這一車': 1, '⋯': 7, '天': 1, '啊': 2, '漂亮': 1, '骨灰': 1, '罈': 1, '紅': 1, '茶': 2, '蜜桃': 1, '果茶': 1, '女兒': 1, '說': 6, '小北': 1, '一瓶': 2, '18': 1, '249': 1, '等': 3, '於': 3, '只要': 1, '10': 1, '塊': 2, '。': 9, '好奇': 1, '想問': 2, '有買過': 1, '這個': 8, '導熱': 1, '效果': 1, '主要': 1, '煎肉': 1, '或者': 1, '其他': 2, '謝謝': 5, '宅': 1, '在家': 2, '多線': 1, '購物': 2, '整理': 3, '房間': 1, '小物': 1, '好物': 1, 'sysmax': 1, '16': 3, '格': 1, '抽屜': 1, '729': 1, '*': 2, '限線': 1, '放': 1, '收納': 1, '附上': 1, '完小': 1, '物照': 1, '內': 1, '份格板': 1, '可': 2, '自由': 1, '運用': 1, '推推': 1, '實測': 1, '小時候': 1, '有過': 1, '一艘': 1, 'Lego': 1, '海盜': 1, '船': 1, '所以': 1, '這款': 4, '3': 1, '合一': 1, '1': 1, '組合': 1, '煞': 1, '不僅': 1, '細節': 1, '滿滿': 1, '還有': 2, ' ...
#      num word
# 0      1  吃得下
# 1      1   東西
# 2      1    吧
# 3      1    塞
# 4      1   小小
# ..   ...  ...
# 878   28    ？
# 879   28    了
# 880   46
# 881   62    ，
# 882   71    的
#
# [883 rows x 2 columns]

# %%
from pymongo import MongoClient
import pandas as pd
#連接MongoDB
client = MongoClient("mongodb+srv://test:test@cluster0.j7nzi.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
#指定資料庫
db = client.costco
#指定資料表
col=db.commodity
#直接從MongoDB查詢
name=col.distinct("商品名稱")
price=col.distinct("商品價格")
web=col.distinct("網址")

df = pd.DataFrame(list(db.commodity.find({},{ "_id": 0, "商品名稱": 1, "商品價格": 1, "網址": 1 })))
df
# Out:
#                                         商品名稱    商品價格  \
# 0                        Angie's 鹹甜爆米花 652公克    $239
# 1                   喜生 冷凍洋蔥牛肉米漢堡 170公克 X 12入    $499
# 2                             宏裕行 冷凍花枝蝦捲 1公斤    $499
# 3            MANUKA Health 麥蘆卡蜂蜜UMF10+ 500公克    $819
# 4                             Kewpie 美奶滋 1公斤    $167
# 5           Kirkland Signature 科克蘭 核桃 1.36公斤    $409
# 6                       UCC 炭燒即溶咖啡 90公克 X 3瓶    $389
# 7                     Godiva 歌帝梵 即溶可可粉 1.4公斤  $1,379
# 8                  黑橋牌 蒜味迷你腸 500公克 X 2入 X 6包  $2,549
# 9                     Cemoi 小熊造型棉花糖牛奶巧克力 2公斤    $497
# 10     Kirkland Signature 科克蘭 無調味綜合堅果 1.13公斤    $659
# 11                      Chosen Foods 酪梨油 1公升    $389
# 12                        卡樂比 富果樂水果早餐麥片 1 公斤    $349
# 13                         得意的一天 三益調和油 3.3公升    $239
# 14     Kirkland Signature 科克蘭 泉水 600毫升 X 30瓶    $319
# 15                               關山一級御用米 9公斤    $635
# 16                  ARM & HAMMER 小蘇打粉 6.12公斤    $299
# 17                             Kewpie 胡麻醬1公升    $229
# 18                           桂格黃金麩片燕麥片 1.7公斤    $249
# 19       Kirkland Signature 科克蘭 橄欖油 3公升 X 2入    $929
# 20                         Koh 純椰子汁 1公升 X 6入    $459
# 21                   Barilla 百味來 義大利粗麵 500公克     $79
# 22                            健司 纖三薯脆片 400公克    $295
# 23                  Starbucks 春季限定咖啡豆 1.13公斤    $699
# 24                              傳六 什錦豆 730公克    $399
# 25             Monbana 1934 70%迦納黑巧克力條 640公克    $559
# 26                          櫻桃爺爺 南棗核桃糕 680公克    $499
# 27     San Pellegrino 聖沛黎洛 天然氣泡水 750毫升 X 12瓶    $539
# 28               Nature's Touch 冷凍野生藍莓 1.5公斤    $315
# 29                           曾拌麵 116公克 X 12包    $429
# 30                        桂格減糖黑十穀 38公克 X 50入    $329
# 31             Perrier 沛綠雅 氣泡礦泉水 500毫升 X 24瓶    $739
# 32        Kirkland Signature 科克蘭 冷凍藍莓 2.27公斤    $539
# 33  Kirkland Signature 科克蘭 韓國鹽烤海苔 17公克 X 10入    $389
# 34                       Daisho 日式燒肉醬 1.15公斤    $189
# 35                         五木細關東麵 416公克 X 9包    $295
# 36                   日本特選和風鰹魚高湯包 8.8公克 X 20包    $319
# 37                       韓味不二 鹽烤海苔 5公克 X 36入    $449
# 38                   桂格 無糖黃金蕎麥多穀飲 28公克 X 50入    $459
# 39                        Mariani 葡萄乾 1.13公斤    $169
# 40                  Starbucks 派克市場咖啡豆 1.13公斤    $699
# 41                       桂格有機燕麥飲 300毫升 X 12入    $329
# 42                             冷凍七星鱸魚排 1.2公斤    $649
# 43       Kirkland Signature 科克蘭 西班牙初榨橄欖油 3公升    $499
# 44                      健司 原味蘇打餅乾 20公克 X 40入    $205
# 45                      Jose's 香草味咖啡豆 1.36公斤    $549
# 46                            新東陽精緻豬肉鬆 270公克    $165
# 47          TableMark 日本讚岐 冷凍烏龍麵 200公克 X 10袋    $265
#
#                                                    網址
# 0   https://www.costco.com.tw/Food/Snacks/Nuts-Chi...
# 1   https://www.costco.com.tw/Food/Frozen-Foods/Pr...
# 2   https://www.costco.com.tw/Food/Frozen-Foods/Pr...
# 3   https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 4   https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 5   https://www.costco.com.tw/Food/Snacks/Nuts-Chi...
# 6   https://www.costco.com.tw/Food/Drinks/Coffee-T...
# 7   https://www.costco.com.tw/Food/Drinks/Powdered...
# 8   https://www.costco.com.tw/Food/Chilled-Fresh-F...
# 9   https://www.costco.com.tw/Food/Snacks/Chocolat...
# 10  https://www.costco.com.tw/Food/Snacks/Nuts-Chi...
# 11  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 12  https://www.costco.com.tw/Food/Drinks/Powdered...
# 13  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 14  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 15  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 16  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 17  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 18  https://www.costco.com.tw/Food/Drinks/Powdered...
# 19  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 20  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 21  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 22  https://www.costco.com.tw/Food/Snacks/Nuts-Chi...
# 23  https://www.costco.com.tw/Food/Drinks/Coffee-T...
# 24  https://www.costco.com.tw/Food/Snacks/Nuts-Chi...
# 25  https://www.costco.com.tw/Food/Snacks/Chocolat...
# 26  https://www.costco.com.tw/Food/Snacks/Cookies-...
# 27  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 28  https://www.costco.com.tw/Food/Frozen-Foods/Fr...
# 29  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 30  https://www.costco.com.tw/Food/Drinks/Powdered...
# 31  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 32  https://www.costco.com.tw/Food/Frozen-Foods/Fr...
# 33  https://www.costco.com.tw/Food/Snacks/Cookies-...
# 34  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 35  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 36  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 37  https://www.costco.com.tw/Food/Snacks/Cookies-...
# 38  https://www.costco.com.tw/Food/Drinks/Powdered...
# 39  https://www.costco.com.tw/Food/Snacks/Cookies-...
# 40  https://www.costco.com.tw/Food/Drinks/Coffee-T...
# 41  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 42  https://www.costco.com.tw/Food/Frozen-Foods/Me...
# 43  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 44  https://www.costco.com.tw/Food/Snacks/Cookies-...
# 45  https://www.costco.com.tw/Food/Drinks/Coffee-T...
# 46  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 47  https://www.costco.com.tw/Food/Frozen-Foods/Pr...

# %%
#資料模糊比對流程整合
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
#FB貼文的斷詞
chart=pd.DataFrame(df_extract) 
#Costco商品列表
chart2=pd.DataFrame(df)

def fuzzy_merge(chart, chart2, key1, key2, threshold=20, limit=1):
    """
    :param df_1: the left table to join
    :param df_2: the right table to join
    :param key1: key column of the left table
    :param key2: key column of the right table
    :param threshold: how close the matches should be to return a match, based on Levenshtein distance
    :param limit: the amount of matches that will get returned, these are sorted high to low
    :return: dataframe with boths keys and matches
    """
    s = chart2[key2].tolist()
    m = chart[key1].apply(lambda x: process.extract(x, s, limit=limit))
    chart['matches'] = m
    m2 = chart['matches'].apply(lambda x: ', '.join([i[0] for i in x if i[1] >= threshold]))
    chart['matches'] = m2
    chart['merge_key'] = chart['matches']
    chart2['merge_key'] = chart2[key2]
    df = pd.merge(chart, chart2, how='left',on='merge_key')
    return df

df = fuzzy_merge(chart,chart2,'word','商品名稱',20)
final=df.drop(['matches','merge_key'],axis=1,inplace=True)

#資料清洗(讀取筆數要改成讀10筆(0~9))
final=df.dropna().sort_values(["num"],ascending=0,ignore_index=True).drop(["num","word"],axis=1)[0:10]
final
# type(final)

#---------------------------------------------------------

import pandas as pd
import tkinter as tk


# --- functions ---

def change(event, row, col):
    # get value from Entry
    value = event.widget.get()
    # set value in dataframe
    final.iloc[row,col] = value
    print(df)

# --- main --    

root = tk.Tk()

# create entry for every element in dataframe

rows, cols = final.shape

for r in range(rows):
    for c in range(cols):
        e = tk.Entry(root)
        e.insert(0, df.iloc[r,c])
        e.grid(row=r, column=c)
        # ENTER
        e.bind('<Return>', lambda event, y=r, x=c: change(event,y,x))
        # ENTER on keypad
        e.bind('<KP_Enter>', lambda event, y=r, x=c: change(event,y,x))

# start program

root.mainloop()
# Out:
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '－']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '=']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '」']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '「']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ',']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '】']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '【']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '&']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '+']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '~']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '”']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '*']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '!']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '..']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '）']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '（']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ':']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ')']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '(']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '￼']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '⋯']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '～']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '。']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '$']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '#']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '！']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '/']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '…']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '？']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '，']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16516/640982024.py in <module>
#      28     return df
#      29
# ---> 30 df = fuzzy_merge(chart,chart2,'word','商品名稱',20)
#      31 final=df.drop(['matches','merge_key'],axis=1,inplace=True)
#      32
#
# ~\AppData\Local\Temp/ipykernel_16516/640982024.py in fuzzy_merge(chart, chart2, key1, key2, threshold, limit)
#      21     m = chart[key1].apply(lambda x: process.extract(x, s, limit=limit))
#      22     chart['matches'] = m
# ---> 23     m2 = chart['matches'].apply(lambda x: ', '.join([i[0] for i in x if i[1] >= threshold]))
#      24     chart['matches'] = m2
#      25     chart['merge_key'] = chart['matches']
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1097                 # "Callable[[Any], Any]"
# -> 1098                 mapped = lib.map_infer(
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp/ipykernel_16516/640982024.py in <lambda>(x)
#      21     m = chart[key1].apply(lambda x: process.extract(x, s, limit=limit))
#      22     chart['matches'] = m
# ---> 23     m2 = chart['matches'].apply(lambda x: ', '.join([i[0] for i in x if i[1] >= threshold]))
#      24     chart['matches'] = m2
#      25     chart['merge_key'] = chart['matches']
#
# TypeError: sequence item 0: expected str instance, float found

# %%
# !pip install tkintertable
# Out:
# Collecting tkintertable
#   Downloading tkintertable-1.3.3.tar.gz (58 kB)
# Requirement already satisfied: future in c:\users\user\anaconda3\lib\site-packages (from tkintertable) (0.18.2)
# Building wheels for collected packages: tkintertable
#   Building wheel for tkintertable (setup.py): started
#   Building wheel for tkintertable (setup.py): finished with status 'done'
#   Created wheel for tkintertable: filename=tkintertable-1.3.3-py3-none-any.whl size=66203 sha256=709601c2af3bc11ab5b371d3ac9f4c453fc1bb62db7124caaa32dbad0e3c849c
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\f1\b0\03\3835e2ae0367eb95366fe276a2ebfcccb1df43d0b506494364
# Successfully built tkintertable
# Installing collected packages: tkintertable
# Successfully installed tkintertable-1.3.3

# %%
from tkintertable import TableCanvas, TableModel
import tkinter as tk
from tkinter import *
import pandas as pd

master = tk.Tk()
master.geometry('400x500')

tframe = Frame(master)
tframe.pack()

data = {'rec1': {'col1': 99.88, 'col2': 108.79, 'label': 'rec1'},
       'rec2': {'col1': 99.88, 'col2': 108.79, 'label': 'rec2'}
       }

table = TableCanvas(tframe, data=data)
table.show()

master.mainloop()
