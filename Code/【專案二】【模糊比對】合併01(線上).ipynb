# %%
from pymongo import MongoClient
import pandas as pd
#連接MongoDB
client = MongoClient("mongodb+srv://test:test@cluster0.j7nzi.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
#指定資料庫
db = client.costco
#指定資料表
col=db.FB_pythons
#直接從MongoDB查詢
post=col.distinct("FB內文")
# data=pd.DataFrame({"FB內文":post})
# print(data)
print(post)
#--------------------------------------------
#將FB內文進行斷詞
import jieba
word=[]
for i in post:
    a=jieba.cut(i)    
    word+=a
print(word)   
#--------------------------------------------
#統計每個字串出現次數
#把每個字串當成key去計算出現的次數(當成值)
dic_w={}
#判斷KEY(ele)是否在dic_w{}裡面
for ele in word:
    #如果KEY(ele)不在dic_w{}裡面,如果KEY沒出現過，就新增一筆KEY並讓值從1開始
    if ele not in dic_w:
        dic_w[ele]=1
    #如果KEY重複出現，值(AKA次數)就+1
    else:
        dic_w[ele]+=1
print(dic_w)
#--------------------------------------------
#調整顯示方式
#因為dic是無序的，所以要用.items來排序呼叫
for ele in dic_w.items():
#     print(ele[0],ele[1])
    #兩個字以上的，才會出現
    if len(ele[0])>=2:
        num=list()
        word=list()
        #因為經過.items的關係，變成(0,1)=(前面,後面)
#         print(ele[0],ele[1])
#--------------------------------------------
#要排序次數
import operator
#itemgetter是指出現該函數內第幾個的意思(從0開始數)
#.itemgetter()從0開始會變成依筆畫排列
sort_w=sorted(dic_w.items(),key=operator.itemgetter(1),reverse=True)
for ele in sort_w:
    num=list()
    word=list()
    for i in range(len(sort_w)):
        a=sort_w.pop()
        num.append(a[1])
        word.append(a[0])    
df_extract=pd.DataFrame({'num':num,'word':word})
print(df_extract)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\user\AppData\Local\Temp\jieba.cache
# ['#冷凍藍莓 #藍莓果醬用這包冷凍藍莓做成果醬一樣好吃這款nature touch的藍莓cp值高，保存容易很適合家庭囤貨。', '#勞動節愉快假日老梗快閃補貨兩串衛生紙跟風團友推薦起司餅乾一度找不到很著急問了工作人員（為了吃使命必達）總是買的比預期的多#今日…… 顯示更多', '#好市多餐食 ', '#宮武讚岐日式炒麵#去骨清雞腿#好菇道雪白菇#黑木耳#鮮香菇…… 顯示更多', '#熨斗去年底在好市多買了飛利浦的熨斗，這個底盤的塗層材質比較特殊，讓燙衣服的時候很滑順很省力，不會卡卡的也就沒有提重物感，對我的媽媽手很友善(雖然我還不是媽媽只是小小上班族XD)光是底盤的塗層就有六層，鈦金屬的材質熨起來連我媽都說很好用很順當初也因為想要買一支可以用很久的熨斗，特別選了含有不鏽鋼比較堅固的底盤，比較耐刮痕，不容易磨損畢竟我公司比較老派，有規定襯衫要燙線，這個不用熨斗很難嚕出來~每隔幾天就要用的工具選好一點也比較方便…… 顯示更多', '#發問#DON萊賽爾單人涼被三件組有人買這嗎？有推或分享文嗎？', '#線上購物第一次在好市多買AppleWatch結果配的是一條不能充電的線o(︶︿︶)o退貨還要去門市然後再重新訂貨沒得當場換貨！想想直接去路口買充電線，順便貼膜買殼～…… 顯示更多', '#芋頭肉鬆奶油酥', '#被隔離的物資朋友友情進貢一箱洋芋片讓我徹底當個沙發馬鈴薯然後這一箱冷泡咖啡第一次喝，還不錯可能我少見多怪，之前都是買超商咖啡沒喝過這種咖啡茶包包的咖啡 挺新奇的…… 顯示更多', '#雀巢金牌濾袋 請問這3款大家都怎麼�
�辣且又是冷凍的方便即食￼…… 顯示更多', '前陣子看到版上有分享蜜蜂工坊的蜂蜜牛奶，今天來內湖店逛才發現竟然也有龍眼蜜！我本來就超愛蜂蜜本人跟蜂蜜類的東西，還記得小時候夏天時，媽媽也很常泡蜂蜜水給我喝，現在快到夏天就就懷念起這個味，…… 顯示更多', '剛才逛好市多線上，發現飛利浦這台萬用鍋有特價了!之前吃過朋友用這台燉的滷肉，肉很嫩湯汁也很濃，當時看他開鍋直接用來炒菜也覺得很方便，感覺可以燉可以炒真的頗萬用，被燒到很想買一台XD一直蹲等終於被我等到優惠，也上來分享分享', '勾豬肉在costco 賣的好便宜！！巧克力冰淇淋家庭號直接是半價唷！然後又有在試吃真是大家福音！！趕快去搶～雪糕6入$399冰淇淋6入$499#冰品', '北台中店有博士倫lacelle的快閃活動了八款顏色任選12盒$2699 還會多送一盒時間是4/29-5/8算下來是比外面買便宜我都戴他們家，韓國進口的品質都不錯…… 顯示更多', '原來有新品種奇異果了10入$269', '原來～沒撒糖粉的是芋泥 有糖粉的是原味！回來記得馬上進冷藏！ 我氣炸鍋180度2分鍾 外酥 內冰   好吃！', '叫老公幫我買個兩箱中筋麵粉搬回來這麼多', '台南店停車場撿到的已送至服務中心', '各位男士們，如果你換了這款後…發現你尿尿時的泡泡怎麼變多了….', '商品情報連結 https://www.daybuy.tw/costco-20112Costco這款椰奶酥 ...
# Loading model cost 0.709 seconds.
# Prefix dict has been built successfully.
# ['#', '冷凍', '藍莓', ' ', '#', '藍莓果', '醬用', '這包', '冷凍', '藍莓', '做', '成果', '醬', '一樣', '好吃', '這款', 'nature', ' ', 'touch', '的', '藍莓', 'cp', '值高', '，', '保存', '容易', '很', '適合', '家庭', '囤貨', '。', '#', '勞動節', '愉快', '假日', '老梗快', '閃補貨', '兩串', '衛生紙', '跟', '風團友', '推薦', '起司餅', '乾', '一度', '找', '不到', '很著', '急問', '了', '工作', '人員', '（', '為', '了', '吃', '使命', '必達', '）', '總是', '買', '的', '比', '預期', '的', '多', '#', '今日', '…', '…', ' ', '顯示', '更', '多', '#', '好市', '多', '餐食', ' ', '#', '宮', '武', '讚', '岐', '日式', '炒', '麵', '#', '去', '骨', '清雞', '腿', '#', '好菇', '道', '雪白', '菇', '#', '黑木耳', '#', '鮮', '香菇', '…', '…', ' ', '顯示', '更', '多', '#', '熨斗', '去年底', '在', '好市', '多', '買', '了', '飛利浦', '的', '熨斗', '，', '這個', '底盤', '的', '塗層', '材質', '比', '較', '特殊', '，', '讓', '燙', '衣服', '的', '時候', '很', '滑順', '很', '省力', '，', '不會', '卡卡', '的', '也', '就', '沒', '有', '提', '重物', '感', '，', '對', '我', '的', '媽媽手', '很', '友善', '(', '雖然', '我還', '不是', '媽媽', '只是', '小小', '上班族', 'XD', ')', '光是', '底盤', '的', '塗層', '就', '有', '六層', '，', '鈦', '金屬', '的', '材質', '熨', '起來連', '我媽', '都', '說', '很', '好', '用', '很', '順當', '初', '也', '因為', '想要', '買', '一支', '可以', '用', '很', '久', '的', '熨斗', '，', '特別', '選', '了', '含有', '不', '鏽', '鋼', '比', '較', '堅', '固', '的', '底', '盤', '，', '比較', '耐', '刮痕', '，', '不', '容易', '磨損', '畢竟', '我', '公司', '比較', '老派', '，', '有', '規定', '襯衫', '要', '燙線', '，', '這個', '不用', '熨斗', '很', '難嚕', '出來', '~', '每隔', '幾天', '就要', '用', '的', '工具', '選好', '一點', '也', '比', '較', '方便', '…', '…', ' ', '顯示', '更', '多', '#', '發問', '#', 'DON', '萊賽爾', '單人涼', '被', '三件', '組', '有人', '買', '這嗎', '？', '有', '推', '或', '分享', '文', '嗎', '？', '#', '線上', '購物', '第一次', '在', '好市', '多', '買', 'AppleWatch', '結果', '配', '的', '是', '一條', '不能', '充電', '的', '線', 'o', '(', '︶', '︿', '︶', ')', 'o', '退貨', '還要', '去', '門市', '然後再', '重新', '訂貨', '沒得', '當場', '換貨', '！', '想想', '直接', '去', '路口', '買', '充電線', '，', '順便', '貼', '膜', '買', '殼', '～', '…', '…', ' ', '顯示', '更', '多', '#', '芋頭', '肉', '鬆', '奶油', '酥', '#', '被', '隔', '離', '的', '物資', '朋友', '友情', '進貢', '一箱', '洋芋片', '讓', '我', '徹底', '當個', '沙發馬鈴', '薯然', '後', '這', '一箱', '冷泡', '咖啡', '第一次', '喝', '，', '還不錯', '可能', '我少見', '多怪', '，', '之前', '都', '是', '買', '超商', '咖啡', '沒', '喝過', '這種', '咖啡茶', '包包', '的', '咖啡', ' ', '挺', '新奇', '的', '…', '…', ' ', '顯示', '更', '多', '#', '雀巢', '金牌', '濾袋', ' ', '請問', '這', '3', '款', '大家', '都', '怎麼', '泡', '呢', '？', '都', '泡', '多少', '水', '？', '#', '飛利浦氣', '炸鍋', 'HD9742', '#', '二次', '焗', '烤馬鈴', '薯燒', '#', '黑卡會員', '&', 'Costco', '信用卡', '沒升級', '黑卡', '以前', '都', '是', '現金', '支付', '（', '以前', '也', '不', '喜歡', '刷', '信用卡', '）', '，', '自從', '升級', '黑卡', '辦理', '信用卡', '後', '老', '是', '會', '忘', '記存', '錢', '到', '裡面', '而', '被扣', '違約金', '（', '沒有', '國泰世華', '其他', '帳戶', '）', '即使', '延遲', '二天', '還是', '一樣', '被扣', '300', '違約金', '，', '感覺', '福利金', '都', '不夠', '我', '賠', '違約', '金', '的', '(', '發文', '於', '2022', '/', '04', '/', '30', ' ', 'PM4', '點多', ')', '.', '現在', '這時', '間點', '入手', ' ', 'iPhone', ' ', '13', ' ', 'Pro', '有人', '會', '說', '不', '建議', '(', '半年', '後', '就', '有', 'iPhone', ' ', '14', '新一代', '上市', ')', '…', '…', ' ', '顯示', '更', '多', '*', '日式', '豬', '排', '丼', '飯', '*', '*', '蝦仁', '蔬菜', '蛋', '炒', '飯', '*', '10', '年', 'ㄧ', '大限', '⋯', '⋯', '4', '/', '29', ' ', '發現', '買', '了', '10', '年', '的', '冷氣', '好像', '壞', '掉', '了', '，', '4', '/', '30', '立馬去', '好市', '多', '買', '了', '開利', '這台', '。', '賣場', '人員', '表示', '要', '1', '～', '2', '天後安裝', '人員才', '會', '安排', '安裝', '時間', '。', '沒', '想到', '我', '騎', '的', '小二輪', '還沒', '回到', '家', '，', '安裝', '人員', '已經', '打', '了', '兩通', '電話', '，', '我', '回', '撥', '後', '又', '因', '剛剛', '沒接', '電話', '，', '導致', '於', '他', '已', '經約別', '人', '了', '，', '如果', '5', '/', '1', '沒安裝', '，', '要', '到', '5', '/', '7', '才', '有', '機會', '…', '就', '在', '我', '與', '對方', '商量', '之際', '，', '他', '：', '明天', '要安裝', '兩', '台大', '台', '的', '，', '會', '很', '累', '…', '我', '：', ' ', '你系', '男子', '漢', 'ㄋ', 'ㄟ', '…', '…', ' ', '顯示', '更', '多', '1KG', '北海道', '生食', '干貝', 'S', ' ', ' ', ' ', '$', '1', ',', '399', '2022', '/', '5', '/', '2', ' ', 'PM15', ':', '25', '誰', '的', '衛生紙', '遺忘', '了', '，', '新莊店', '2', '樓', '-', '輪胎', '中心', '對面', '，', '推車', '放置', '區', '，', '因為', '自己 ...
# {'#': 43, '冷凍': 7, '藍莓': 3, ' ': 173, '藍莓果': 1, '醬用': 1, '這包': 1, '做': 10, '成果': 1, '醬': 3, '一樣': 10, '好吃': 27, '這款': 21, 'nature': 1, 'touch': 1, '的': 278, 'cp': 1, '值高': 1, '，': 332, '保存': 2, '容易': 4, '很': 57, '適合': 3, '家庭': 3, '囤貨': 1, '。': 53, '勞動節': 1, '愉快': 1, '假日': 1, '老梗快': 1, '閃補貨': 1, '兩串': 1, '衛生紙': 2, '跟': 24, '風團友': 1, '推薦': 12, '起司餅': 1, '乾': 6, '一度': 1, '找': 5, '不到': 4, '很著': 1, '急問': 1, '了': 121, '工作': 2, '人員': 4, '（': 28, '為': 7, '吃': 34, '使命': 1, '必達': 1, '）': 28, '總是': 1, '買': 80, '比': 18, '預期': 1, '多': 85, '今日': 4, '…': 103, '顯示': 43, '更': 46, '好市': 35, '餐食': 1, '宮': 1, '武': 1, '讚': 6, '岐': 1, '日式': 3, '炒': 6, '麵': 10, '去': 21, '骨': 1, '清雞': 1, '腿': 2, '好菇': 1, '道': 2, '雪白': 1, '菇': 2, '黑木耳': 1, '鮮': 1, '香菇': 1, '熨斗': 4, '去年底': 1, '在': 39, '飛利浦': 2, '這個': 28, '底盤': 2, '塗層': 2, '材質': 2, '較': 12, '特殊': 1, '讓': 8, '燙': 1, '衣服': 1, '時候': 6, '滑順': 1, '省力': 1, '不會': 6, '卡卡': 1, '也': 34, '就': 34, '沒': 37, '有': 78, '提': 1, '重物': 1, '感': 2, '對': 8, '我': 82, '媽媽手': 1, '友善': 1, '(': 10, '雖然': 2, '我還': 1, '不是': 12, '媽媽': 2, '只是': 3, '小小': 2, '上班族': 1, 'XD': 2, ')': 10, '光是': 1, '六層': 1, '鈦': 1, '金屬': 1, '熨': 1, '起來連': 1, '我媽': 1, '都': 49, '說': 22, '好': 34, '用': 18, '順當': 1, '初': 1, '因為': 11, '想要': 1, '一支': 2, '可以': 31, '久': 4, '特別': 4, '選': 1, '含有': 1, '不': 30, '鏽': 1, '鋼': 1, '堅
'立馬去': 1, '開利': 1, '這台': 7, '賣場': 5, '表示': 2, '1': 9, '2': 9, '天後安裝': 1, '人員才': 1, '安排': 2, '安裝': 4, '時間': 3, '想到': 5, '騎': 1, '小二輪': 1, '還沒': 1, '回到': 2, '家': 4, '已經': 8, '打': 5, '兩通': 1, '電話': 2, '回': 1, '撥': 1, '又': 20, '因': 2, '剛剛': 3, '沒接': 1, '導致': 1, '他': 11, '已': 5, '經約別': 1, '人': 12, '如果': 3, '5': 7, '沒安裝': 1, '7': 4, '才': 12, '機會': 1, '與': 3, '對方': 1, '商量': 1, '之際': 1, '：': 10, '明天': 1, '要安裝': 1, '兩': 1, '台大': 1, '台': 3, '累': 1, '你系': 1, '男子': 1, '漢': 1, 'ㄋ': 1, 'ㄟ': 1, '1KG': 1, '北海道': 1, '生食': 1, '干貝': 2, 'S': 2, '$': 18, ',': 8, '399': 2, 'PM15': 1, ':': 11, '25': 3, '誰': 2, '遺忘': 1, '新莊店': 1, '樓': 1, '-': 19, '輪胎': 1, '中心': 7, '對面': 1, '推車': 3, '放置': 1, '區': 1, '自己': 11, '急事': 1, '先行': 1, '離開': 1, '3M': 1, '口罩': 6, '買過': 8, '感受': 1, '因其': 1, '價格': 3, '一般': 2, '貴': 2, '謝謝': 10, 'BARK': 1, '寵物':  ...
#       num word
# 0       1  吃得下
# 1       1    塞
# 2       1   ml
# 3       1   便當
# 4       1   太少
# ...   ...  ...
# 2566  103    …
# 2567  121    了
# 2568  173
# 2569  278    的
# 2570  332    ，
#
# [2571 rows x 2 columns]

# %%
from pymongo import MongoClient
import pandas as pd
#連接MongoDB
client = MongoClient("mongodb+srv://test:test@cluster0.j7nzi.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
#指定資料庫
db = client.costco
#指定資料表
col=db.commodity
#直接從MongoDB查詢
name=col.distinct("商品名稱")
price=col.distinct("商品價格")
web=col.distinct("網址")

df = pd.DataFrame(list(db.commodity.find({},{ "_id": 0, "商品名稱": 1, "商品價格": 1, "網址": 1 })))
df
# Out:
#                                         商品名稱    商品價格  \
# 0                        Angie's 鹹甜爆米花 652公克    $239
# 1                   喜生 冷凍洋蔥牛肉米漢堡 170公克 X 12入    $499
# 2                             宏裕行 冷凍花枝蝦捲 1公斤    $499
# 3            MANUKA Health 麥蘆卡蜂蜜UMF10+ 500公克    $819
# 4                             Kewpie 美奶滋 1公斤    $167
# 5           Kirkland Signature 科克蘭 核桃 1.36公斤    $409
# 6                       UCC 炭燒即溶咖啡 90公克 X 3瓶    $389
# 7                     Godiva 歌帝梵 即溶可可粉 1.4公斤  $1,379
# 8                  黑橋牌 蒜味迷你腸 500公克 X 2入 X 6包  $2,549
# 9                     Cemoi 小熊造型棉花糖牛奶巧克力 2公斤    $497
# 10     Kirkland Signature 科克蘭 無調味綜合堅果 1.13公斤    $659
# 11                      Chosen Foods 酪梨油 1公升    $389
# 12                        卡樂比 富果樂水果早餐麥片 1 公斤    $349
# 13                         得意的一天 三益調和油 3.3公升    $239
# 14     Kirkland Signature 科克蘭 泉水 600毫升 X 30瓶    $319
# 15                               關山一級御用米 9公斤    $635
# 16                  ARM & HAMMER 小蘇打粉 6.12公斤    $299
# 17                             Kewpie 胡麻醬1公升    $229
# 18                           桂格黃金麩片燕麥片 1.7公斤    $249
# 19       Kirkland Signature 科克蘭 橄欖油 3公升 X 2入    $929
# 20                         Koh 純椰子汁 1公升 X 6入    $459
# 21                   Barilla 百味來 義大利粗麵 500公克     $79
# 22                            健司 纖三薯脆片 400公克    $295
# 23                  Starbucks 春季限定咖啡豆 1.13公斤    $699
# 24                              傳六 什錦豆 730公克    $399
# 25             Monbana 1934 70%迦納黑巧克力條 640公克    $559
# 26                          櫻桃爺爺 南棗核桃糕 680公克    $499
# 27     San Pellegrino 聖沛黎洛 天然氣泡水 750毫升 X 12瓶    $539
# 28               Nature's Touch 冷凍野生藍莓 1.5公斤    $315
# 29                           曾拌麵 116公克 X 12包    $429
# 30                        桂格減糖黑十穀 38公克 X 50入    $329
# 31             Perrier 沛綠雅 氣泡礦泉水 500毫升 X 24瓶    $739
# 32        Kirkland Signature 科克蘭 冷凍藍莓 2.27公斤    $539
# 33  Kirkland Signature 科克蘭 韓國鹽烤海苔 17公克 X 10入    $389
# 34                       Daisho 日式燒肉醬 1.15公斤    $189
# 35                         五木細關東麵 416公克 X 9包    $295
# 36                   日本特選和風鰹魚高湯包 8.8公克 X 20包    $319
# 37                       韓味不二 鹽烤海苔 5公克 X 36入    $449
# 38                   桂格 無糖黃金蕎麥多穀飲 28公克 X 50入    $459
# 39                        Mariani 葡萄乾 1.13公斤    $169
# 40                  Starbucks 派克市場咖啡豆 1.13公斤    $699
# 41                       桂格有機燕麥飲 300毫升 X 12入    $329
# 42                             冷凍七星鱸魚排 1.2公斤    $649
# 43       Kirkland Signature 科克蘭 西班牙初榨橄欖油 3公升    $499
# 44                      健司 原味蘇打餅乾 20公克 X 40入    $205
# 45                      Jose's 香草味咖啡豆 1.36公斤    $549
# 46                            新東陽精緻豬肉鬆 270公克    $165
# 47          TableMark 日本讚岐 冷凍烏龍麵 200公克 X 10袋    $265
#
#                                                    網址
# 0   https://www.costco.com.tw/Food/Snacks/Nuts-Chi...
# 1   https://www.costco.com.tw/Food/Frozen-Foods/Pr...
# 2   https://www.costco.com.tw/Food/Frozen-Foods/Pr...
# 3   https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 4   https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 5   https://www.costco.com.tw/Food/Snacks/Nuts-Chi...
# 6   https://www.costco.com.tw/Food/Drinks/Coffee-T...
# 7   https://www.costco.com.tw/Food/Drinks/Powdered...
# 8   https://www.costco.com.tw/Food/Chilled-Fresh-F...
# 9   https://www.costco.com.tw/Food/Snacks/Chocolat...
# 10  https://www.costco.com.tw/Food/Snacks/Nuts-Chi...
# 11  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 12  https://www.costco.com.tw/Food/Drinks/Powdered...
# 13  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 14  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 15  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 16  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 17  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 18  https://www.costco.com.tw/Food/Drinks/Powdered...
# 19  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 20  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 21  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 22  https://www.costco.com.tw/Food/Snacks/Nuts-Chi...
# 23  https://www.costco.com.tw/Food/Drinks/Coffee-T...
# 24  https://www.costco.com.tw/Food/Snacks/Nuts-Chi...
# 25  https://www.costco.com.tw/Food/Snacks/Chocolat...
# 26  https://www.costco.com.tw/Food/Snacks/Cookies-...
# 27  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 28  https://www.costco.com.tw/Food/Frozen-Foods/Fr...
# 29  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 30  https://www.costco.com.tw/Food/Drinks/Powdered...
# 31  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 32  https://www.costco.com.tw/Food/Frozen-Foods/Fr...
# 33  https://www.costco.com.tw/Food/Snacks/Cookies-...
# 34  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 35  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 36  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 37  https://www.costco.com.tw/Food/Snacks/Cookies-...
# 38  https://www.costco.com.tw/Food/Drinks/Powdered...
# 39  https://www.costco.com.tw/Food/Snacks/Cookies-...
# 40  https://www.costco.com.tw/Food/Drinks/Coffee-T...
# 41  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 42  https://www.costco.com.tw/Food/Frozen-Foods/Me...
# 43  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 44  https://www.costco.com.tw/Food/Snacks/Cookies-...
# 45  https://www.costco.com.tw/Food/Drinks/Coffee-T...
# 46  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 47  https://www.costco.com.tw/Food/Frozen-Foods/Pr...

# %%
# !pip install fuzzywuzzy
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %%
#資料模糊比對流程整合
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
#FB貼文的斷詞
chart=pd.DataFrame(df_extract) 
#Costco商品列表
chart2=pd.DataFrame(df)

def fuzzy_merge(chart, chart2, key1, key2, threshold=20, limit=1):
    """
    :param df_1: the left table to join
    :param df_2: the right table to join
    :param key1: key column of the left table
    :param key2: key column of the right table
    :param threshold: how close the matches should be to return a match, based on Levenshtein distance
    :param limit: the amount of matches that will get returned, these are sorted high to low
    :return: dataframe with boths keys and matches
    """
    s = chart2[key2].tolist()
    m = chart[key1].apply(lambda x: process.extract(x, s, limit=limit))
    chart['matches'] = m
    m2 = chart['matches'].apply(lambda x: ', '.join([i[0] for i in x if i[1] >= threshold]))
    chart['matches'] = m2
    chart['merge_key'] = chart['matches']
    chart2['merge_key'] = chart2[key2]
    df = pd.merge(chart, chart2, how='left',on='merge_key')
    return df

df = fuzzy_merge(chart,chart2,'word','商品名稱',20)
final=df.drop(['matches','merge_key'],axis=1,inplace=True)

#資料清洗(讀取筆數要改成讀10筆(0~9))
final=df.dropna().sort_values(["num"],ascending=0,ignore_index=True).drop(["num","word"],axis=1)[0:10]
# print(final)
# final
type(final)
# Out:
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '』']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '『']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '🫣']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-------------']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-----------']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '--------------']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '－']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '＋']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '=']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '》']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '《']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '︿']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '“']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '....']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '&']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '︶']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '+']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '🫠']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '】']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '【']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '..']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '”']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '...']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '*']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '~']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ',']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '⁡']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '!']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '」']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '「']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '：']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ')']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '(']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ':']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '、']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '$']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '⋯']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '￼']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '）']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '（']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '～']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '#']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '/']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '。']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '？']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '！']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '…']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '，']
# pandas.core.frame.DataFrame

# %%
#TKinter
import tkinter as tk
import pandas as pd
import os
import time
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import random
import pandas as pd
import pymongo
from pymongo import MongoClient
from tkinter import filedialog,messagebox,ttk

#TKinter開頭
win=tk.Tk()
win.title("Costco最新熱門食品推薦榜") #改寫視窗標題
win.geometry("480x1000") #視窗大小 寬x長
win.resizable(True,True) #鎖定視窗大小 寬,長
win.iconbitmap("cart.ico") #改變視窗icon，下載ico檔後放在user資料夾
win.config(bg="#F0F0F0") #改變視窗顏色
# win.attributes("-topmost",True) #視窗置頂

# #Costco清單1
# def shoplist1(): 
# btn.config(text="手刀購買去👇")

# #Costco清單2
# def shoplist2(): 
# btn.config(text="手刀購買去👇")

#TKinter排版
img=tk.PhotoImage(file="costco.png") #定義圖片物件
lbtop=tk.Label()
lbtop.config(image=img) #將按鈕外觀設定為圖片
lbtop.grid(column=4,row=0,pady=5)

lbscript=tk.Label(text="😋想在Costco找好吃的，不怕選擇障礙沒靈感，抓住最新趨勢就看這裡買!🛒") #定義標籤
lbscript.config(bg="#000404",fg="#F8F8F8") #設定標籤顏色屬性
lbscript.grid(column=4,row=1,pady=10) #打包label到視窗

pd.set_option('display.unicode.ambiguous_as_wide', True)
pd.set_option('display.unicode.east_asian_width', True)

# btn=tk.Button(text='點我產生…')
# btn.config(bg='#0C2D50',fg='#F8F9F9',command=shoplist1) #,command=shoplist1
# btn.grid(column=4,row=2,pady=5)

lb2=tk.Label(text="全通路TOP10")
lb2.config(bg="#000404",fg="#F8F8F8") 
lb2.grid(column=4,row=3,pady=5) 

lb3=ttk.Labelframe(win,text='final')
# lb3=tk.Label(text=final,justify="left") #text=
lb3.config(bg="#F0F0F0",fg="#000404")
lb3.grid(column=1,row=4,columnspan=4,rowspan=10,pady=20)


#10個連結btn
from tkinter import *
import webbrowser

def callback(url):
    webbrowser.open_new(url)

link1 = Label(text="商品連結1", fg="blue", cursor="hand2")
link1.grid(column=5,row=5)
link1.bind("<Button-1>", lambda e: callback(complete.iat[0,2]))
link2 = Label(text="商品連結2", fg="blue", cursor="hand2")
link2.grid(column=5,row=6)
link2.bind("<Button-1>", lambda e: callback(complete.iat[1,2]))
link3 = Label(text="商品連結3", fg="blue", cursor="hand2")
link3.grid(column=5,row=7)
link3.bind("<Button-1>", lambda e: callback(complete.iat[2,2]))
link4 = Label(text="商品連結4", fg="blue", cursor="hand2")
link4.grid(column=5,row=8)
link4.bind("<Button-1>", lambda e: callback(complete.iat[3,2]))
link5 = Label(text="商品連結5", fg="blue", cursor="hand2")
link5.grid(column=5,row=9)
link5.bind("<Button-1>", lambda e: callback(complete.iat[4,2]))
link6 = Label(text="商品連結6", fg="blue", cursor="hand2")
link6.grid(column=5,row=10)
link6.bind("<Button-1>", lambda e: callback(complete.iat[5,2]))
link7 = Label(text="商品連結7", fg="blue", cursor="hand2")
link7.grid(column=5,row=11)
link7.bind("<Button-1>", lambda e: callback(complete.iat[6,2]))
link8 = Label(text="商品連結8", fg="blue", cursor="hand2")
link8.grid(column=5,row=12)
link8.bind("<Button-1>", lambda e: callback(complete.iat[7,2]))
link9 = Label(text="商品連結9", fg="blue", cursor="hand2")
link9.grid(column=5,row=13)
link9.bind("<Button-1>", lambda e: callback(complete.iat[8,2]))
link10 = Label(text="商品連結10", fg="blue", cursor="hand2")
link10.grid(column=5,row=14)
link10.bind("<Button-1>", lambda e: callback(complete.iat[9,2]))



win.mainloop() #讓win在螢幕上持續運行
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1336/401339376.py in <module>
#      54 lb3=ttk.Labelframe(win,text='final')
#      55 # lb3=tk.Label(text=final,justify="left") #text=
# ---> 56 lb3.config(bg="#F0F0F0",fg="#000404")
#      57 lb3.grid(column=1,row=4,columnspan=4,rowspan=10,pady=20)
#      58
#
# ~\anaconda3\lib\tkinter\__init__.py in configure(self, cnf, **kw)
#    1644         the allowed keyword arguments call the method keys.
#    1645         """
# -> 1646         return self._configure('configure', cnf, kw)
#    1647
#    1648     config = configure
#
# ~\anaconda3\lib\tkinter\__init__.py in _configure(self, cmd, cnf, kw)
#    1634         if isinstance(cnf, str):
#    1635             return self._getconfigure1(_flatten((self._w, cmd, '-'+cnf)))
# -> 1636         self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
#    1637     # These used to be defined in Widget:
#    1638
#
# TclError: unknown option "-bg"
