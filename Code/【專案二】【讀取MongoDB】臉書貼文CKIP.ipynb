# %%
from pymongo import MongoClient
import pandas as pd
#連接MongoDB
client = MongoClient("mongodb+srv://test:test@cluster0.j7nzi.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
#指定資料庫
db = client.costco
#指定資料表
col=db.FB_pythons
#直接從MongoDB查詢獲取SourceCode
post=col.distinct("FB內文")
data=pd.DataFrame({"FB內文":post})
print(data)
print(post)
# Out:
#                                                   FB內文
# 0    #LaboLabo毛孔緊緻早晚安面膜組 #兩入589元前陣子才在賣場看到LaboLabo的洗...
# 1                               #卡士達可頌#芋泥可頌6個198 新品 好吃
# 2    #地表最簡略的購物清單前陣子老媽傳了張截圖跟我說要買這些我一看，沒品牌沒品名只好從家裡最常用...
# 3    #好市多肉鬆肉鬆蛋餅女兒睡前說早餐想吃蛋餅蛋餅裡放了她最愛的肉鬆可能是很久沒吃蛋餅了…… 顯示更多
# 4    #好市多蝦子海苔蝦小飯糰最近找到一個沒什麼人煙的公園假日帶孩子去消耗體力寬敞的大公園孩子玩得...
# ..                                                 ...
# 224  還不錯吃，加熱的時候加點水跟想吃的青菜女生一個人吃剛剛好微辣很舒服裡面的馬鈴薯好吃是Q的豬肉...
# 225  酸的實在無法吃了4/23後續 本來打算要拿去退貨的，有一網友建議煮果醬；於是就開始準備起來-...
# 226  長期以來都很愛吃黑色的辛拉麵，回購過好多次了，最近迷上看某營養師的YouTube影片，午餐要...
# 227                                              鮮奶漲價嚕
# 228  ［分享］我有打去問客服個人升黑鑽卡的優惠（假設有costco聯名信用卡）給大家參考不升黑卡年...
#
# [229 rows x 1 columns]
# ...

# %%
from ckiptagger import data_utils
data_utils.download_data_gdown("./")

from ckiptagger import WS, POS, NER

sentence_list = [post]
ws = WS("./data")
pos = POS("./data")
ner = NER("./data")

ws_results =ws(sentence_list,
               sentence_segmentation=True,
               segment_delimiter_set={'?','？','!','！','。',',',',',';',':','、'})
pos_results = pos(ws_results)
# ner_results = ner(ws_results, pos_results)
# pos_results = pos(ws_results)
# ner_results = ner(ws_results, pos_results)

print(ws_results)
print(pos_results)
# for name in ner_results[0]:
#     print(name)
# Out:
# Access denied with the following error:
#  	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
#
# You may still be able to access the file from the browser:
#
# 	 https://drive.google.com/uc?id=1efHsY16pxK0lBD2gYCgCTnv1Swstq771
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10832/3559445476.py in <module>
#      12                sentence_segmentation=True,
#      13                segment_delimiter_set={'?','？','!','！','。',',',',',';',':','、'})
# ---> 14 pos_results = pos(ws_results)
#      15 # ner_results = ner(ws_results, pos_results)
#      16 # pos_results = pos(ws_results)
#
# ...

# %%
ner_results = ner(ws_results, pos_results)
print(ner_results)
# Out:
# [{(1401, 1403, 'GPE', '好市'), (1232, 1234, 'DATE', '今年'), (1392, 1394, 'GPE', '好市'), (1651, 1653, 'GPE', '台南'), (1551, 1553, 'GPE', '台南'), (1580, 1583, 'GPE', '台南特'), (1155, 1157, 'DATE', '今天'), (1624, 1626, 'PERSON', '太陽'), (3887, 3889, 'PERSON', '瑜珈'), (1610, 1612, 'GPE', '台南'), (2225, 2227, 'CARDINAL', '64'), (1133, 1135, 'DATE', '今天'), (3413, 3415, 'GPE', '台北'), (3646, 3648, 'GPE', '澳洲'), (3861, 3863, 'PERSON', '瑜珈'), (3109, 3113, 'CARDINAL', '7/10'), (4696, 4699, 'TIME', '一歲半'), (4764, 4768, 'CARDINAL', '1139'), (1089, 1091, 'DATE', '今天'), (1143, 1145, 'ORDINAL', '第一'), (1380, 1383, 'PERSON', '謝宗霖'), (1482, 1484, 'GPE', '好市'), (1960, 1963, 'CARDINAL', '一千五'), (3495, 3497, 'GPE', '北部'), (2612, 2614, 'GPE', '中壢'), (1573, 1576, 'ORG', '台南店'), (4052, 4054, 'GPE', '好市'), (1191, 1193, 'PERSON', '南崁'), (389, 391, 'TIME', '今天'), (4106, 4108, 'GPE', '北部'), (5143, 5145, 'GPE', '北部'), (2887, 2889, 'GPE', '台南'), (1480, 1482, 'GPE', '台中'), (1399, 1401, 'GPE', '台南'), (2889, 2891, 'GPE', '好市'),
# ...

# %%
temp_w=[{(1401, 1403, 'GPE', '好市'), (1232, 1234, 'DATE', '今年'), (1392, 1394, 'GPE', '好市'), (1651, 1653, 'GPE', '台南'), (1551, 1553, 'GPE', '台南'), (1580, 1583, 'GPE', '台南特'), (1155, 1157, 'DATE', '今天'), (1624, 1626, 'PERSON', '太陽'), (3887, 3889, 'PERSON', '瑜珈'), (1610, 1612, 'GPE', '台南'), (2225, 2227, 'CARDINAL', '64'), (1133, 1135, 'DATE', '今天'), (3413, 3415, 'GPE', '台北'), (3646, 3648, 'GPE', '澳洲'), (3861, 3863, 'PERSON', '瑜珈'), (3109, 3113, 'CARDINAL', '7/10'), (4696, 4699, 'TIME', '一歲半'), (4764, 4768, 'CARDINAL', '1139'), (1089, 1091, 'DATE', '今天'), (1143, 1145, 'ORDINAL', '第一'), (1380, 1383, 'PERSON', '謝宗霖'), (1482, 1484, 'GPE', '好市'), (1960, 1963, 'CARDINAL', '一千五'), (3495, 3497, 'GPE', '北部'), (2612, 2614, 'GPE', '中壢'), (1573, 1576, 'ORG', '台南店'), (4052, 4054, 'GPE', '好市'), (1191, 1193, 'PERSON', '南崁'), (389, 391, 'TIME', '今天'), (4106, 4108, 'GPE', '北部'), (5143, 5145, 'GPE', '北部'), (2887, 2889, 'GPE', '台南'), (1480, 1482, 'GPE', '台中'), (1399, 1401, 'GPE', '台南'), (2889, 2891, 'GPE', '好市'), (1197, 1199, 'DATE', '今天'), (1209, 1211, 'DATE', '今天'), (1912, 1915, 'GPE', '台灣市'), (4138, 4140, 'GPE', '台南'), (1476, 1478, 'GPE', '好市'), (2659, 2661, 'PERSON', '謝謝'), (4108, 4110, 'GPE', '好市'), (3107, 3109, 'ORG', '北部'), (97, 99, 'PERSON', '大大'), (1136, 1138, 'GPE', '台南'), (4261, 4263, 'CARDINAL', '26'), (2490, 2492, 'CARDINAL', '16'), (2534, 2536, 'DATE', '今天'), (2291, 2293, 'DATE', '今天')}]

# %%
type(temp_w[0]),len(temp_w[0]),temp_w[0]
temp_w[0]

# #統計每個字串出現次數
# #把每個字串當成key去計算出現的次數(當成值)
# a=ner_results[0]
# dic_w={}
# #判斷KEY(ele)是否在dic_w{}裡面
# for ele in a:
#     #如果KEY(ele)不在dic_w{}裡面,如果KEY沒出現過，就新增一筆KEY並讓值從1開始
#     if ele not in dic_w:
#         dic_w[ele]=1
#     #如果KEY重複出現，值(AKA次數)就+1
#     else:
#         dic_w[ele]+=1
# print(dic_w)
# Out:
# {(97, 99, 'PERSON', '大大'),
#  (389, 391, 'TIME', '今天'),
#  (1089, 1091, 'DATE', '今天'),
#  (1133, 1135, 'DATE', '今天'),
#  (1136, 1138, 'GPE', '台南'),
#  (1143, 1145, 'ORDINAL', '第一'),
#  (1155, 1157, 'DATE', '今天'),
#  (1191, 1193, 'PERSON', '南崁'),
#  (1197, 1199, 'DATE', '今天'),
#  (1209, 1211, 'DATE', '今天'),
#  (1232, 1234, 'DATE', '今年'),
#  (1380, 1383, 'PERSON', '謝宗霖'),
#  (1392, 1394, 'GPE', '好市'),
#  (1399, 1401, 'GPE', '台南'),
#  (1401, 1403, 'GPE', '好市'),
#  (1476, 1478, 'GPE', '好市'),
#  (1480, 1482, 'GPE', '台中'),
#  (1482, 1484, 'GPE', '好市'),
#  (1551, 1553, 'GPE', '台南'),
#  (1573, 1576, 'ORG', '台南店'),
#  (1580, 1583, 'GPE', '台南特'),
#  (1610, 1612, 'GPE', '台南'),
#  (1624, 1626, 'PERSON', '太陽'),
#  (1651, 1653, 'GPE', '台南'),
#  (1912, 1915, 'GPE', '台灣市'),
#  (1960, 1963, 'CARDINAL', '一千五'),
#  (2225, 2227, 'CARDINAL', '64'),
#  (2291, 2293, 'DATE', '今天'),
#  (2490, 2492, 'CARDINAL', '16'),
#  (2534, 2536, 'DATE', '今天'),
#  (2612, 2614, 'GPE', '中壢'),
# ...

# %%
# type(ner_results[0]),len(ner_results[0]),ner_results[0]
t=temp_w[0].pop()
type(t),t
# Out:
# (tuple, (1232, 1234, 'DATE', '今年'))

# %%
df_class_list=list()
df_ner_list=list()

for i in range(len(temp_w[0])):
    a=temp_w[0].pop()
    df_class_list.append(a[2])
    df_ner_list.append(a[3])
    
df_extract=pd.DataFrame({'類別':df_class_list,'專有名詞':df_ner_list})
# print(df_extract)

freq = df_extract.groupby(['專有名詞']).count() 
print(freq)

df_extract.sort_values('類別',ignore_index=True)
# Out:
#       類別
# 專有名詞
# 1139   1
# 16     1
# 26     1
# 64     1
# 7/10   1
# 一千五    1
# 一歲半    1
# 中壢     1
# 今天     8
# 北部     4
# 南崁     1
# 台中     1
# 台北     1
# 台南     7
# 台南店    1
# 台南特    1
# 台灣市    1
# 大大     1
# 太陽     1
# 好市     6
# 澳洲     1
# 瑜珈     2
# 第一     1
# 謝宗霖    1
# 謝謝     1
#           類別  專有名詞
# 0   CARDINAL    16
# 1   CARDINAL    26
# 2   CARDINAL   一千五
# 3   CARDINAL  1139
# 4   CARDINAL  7/10
# 5   CARDINAL    64
# 6       DATE    今天
# 7       DATE    今天
# 8       DATE    今天
# 9       DATE    今天
# 10      DATE    今天
# 11      DATE    今天
# 12      DATE    今天
# 13       GPE   台灣市
# 14       GPE    北部
# 15       GPE    台南
# 16       GPE    好市
# 17       GPE    好市
# 18       GPE    好市
# 19       GPE    台南
# 20       GPE    台中
# 21       GPE    台南
# 22       GPE    台南
# 23       GPE    北部
# 24       GPE    好市
# 25       GPE    台北
# 26       GPE    台南
# 27       GPE    中壢
# 28       GPE    北部
# 29       GPE    好市
# 30       GPE    台南
# 31       GPE   台南特
# ...

# %%
type(df_extract)
# Out:
# pandas.core.frame.DataFrame

# %%
#要排序次數
import operator
#itemgetter是指出現該函數內第幾個的意思(從0開始數)
#.itemgetter()從0開始會變成依筆畫排列
sort_w=sorted(freq,key=operator.itemgetter(1),reverse=True)
print(sort_w)
for ele in sort_w:
    if len(ele[0])>=3:
        print(ele[0],ele[1])
# Out:
# ['類別']
