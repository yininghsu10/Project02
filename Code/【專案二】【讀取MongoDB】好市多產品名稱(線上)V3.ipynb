# %%
from pymongo import MongoClient
import pandas as pd
#連接MongoDB
client = MongoClient("mongodb+srv://test:test@cluster0.j7nzi.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
#指定資料庫
db = client.costco
#指定資料表
col=db.commodity
#直接從MongoDB查詢
name=col.distinct("商品名稱")
price=col.distinct("商品價格")
web=col.distinct("網址")

df = pd.DataFrame(list(db.commodity.find({},{ "_id": 0, "商品名稱": 1, "商品價格": 1, "網址": 1 })))
# print(pd.DataFrame.from_dict(df))
df
# # for x in col.find({},{ "_id": 0, "商品名稱": 1, "商品價格": 1, "網址": 1 }):
# my_dict = {'商品名稱':name,'商品價格':price,'網址':web}
# df = pd.DataFrame([my_dict])
# df
# df.style.set_properties(**{'text-align': 'right'})
#     a=pd.DataFrame(x.values())
#     b=pd.DataFrame(x.keys())
#     c=(list(x.values()))
#     d=[x]
#     print(d)
# #     df=pd.DataFrame(d)
#     print(df)
#     print(c)

#     print(a)
#     print(b)

#     print(df)
# type(name)
# print(price)
# print(web)
# Out:
#                                          商品名稱    商品價格  \
# 0                  雀巢 金牌冰萃濾袋研磨咖啡 10 公克 X 40 包    $319
# 1                         Angie's 鹹甜爆米花 652公克    $239
# 2                              宏裕行 冷凍花枝蝦捲 1公斤    $499
# 3                              Kewpie 美奶滋 1公斤    $167
# 4       Kirkland Signature 科克蘭 義式深焙咖啡豆 1.13公斤    $369
# 5             MANUKA Health 麥蘆卡蜂蜜UMF10+ 500公克    $819
# 6                            櫻桃爺爺 南棗核桃糕 680公克    $409
# 7            Kirkland Signature 科克蘭 核桃 1.36公斤    $409
# 8                     Welch's 葡萄汁 2.84公升 X 2入    $409
# 9                      Godiva 歌帝梵 即溶可可粉 1.4公斤  $1,379
# 10                        老協珍 冷凍青木瓜排骨煲湯1730公克    $559
# 11      Kirkland Signature 科克蘭 無調味綜合堅果 1.13公斤    $659
# 12                     桂格 夏日穀珍綜合莓果 30公克 X 36包    $299
# 13                       愛之味 純濃燕麥 340毫升 X 12入    $299
# 14              Monbana 1934 70%迦納黑巧克力條 640公克    $559
# 15          Alphamic 食物烹調專用紙 30公分 X 50公尺 X 2入    $379
# 16                               傳六 什錦豆 730公克    $399
# 17                         卡樂比 富果樂水果早餐麥片 1 公斤    $349
# 18                       Chosen Foods 酪梨油 1公升    $389
# 19                     樂天 優格風味碳酸飲 250毫升 X 30入    $459
# 20                   Evian 天然礦泉水 1500毫升 X 12入    $639
# 21      Kirkland Signature 科克蘭 泉水 600毫升 X 30瓶    $319
# 22  Starbucks  Veranda Blend 黃金烘焙綜合咖啡豆 1.13公斤    $699
# 23                             冷凍比目魚切片 1.15公斤    $639
# 24                              Kewpie 胡麻醬1公升    $229
# 25                    Barilla 百味來 義大利粗麵 500公克     $79
# 26                            曾拌麵 116公克 X 12包    $429
# 27        Kirkland Signature 科克蘭 橄欖油 3公升 X 2入    $929
# 28              Perrier 沛綠雅 氣泡礦泉水 500毫升 X 24瓶    $739
# 29                            日清 奶油三明治 1270公克    $309
# 30                          五木細關東麵 416公克 X 9包    $295
# 31                   Starbucks 春季限定咖啡豆 1.13公斤    $699
# 32                         桂格減糖黑十穀 38公克 X 50入    $329
# 33                          Koh 純椰子汁 1公升 X 6入    $459
# 34                                關山一級御用米 9公斤    $635
# 35                      克寧 核桃燕麥牛乳 198毫升 X 24入    $329
# 36                            桂格黃金麩片燕麥片 1.7公斤    $249
# 37   Kirkland Signature 科克蘭 韓國鹽烤海苔 17公克 X 10入    $389
# 38                             健司 纖三薯脆片 400公克    $295
# 39                   ARM & HAMMER 小蘇打粉 6.12公斤    $299
# 40                   Starbucks 派克市場咖啡豆 1.13公斤    $699
# 41                        韓味不二 鹽烤海苔 5公克 X 36入    $449
# 42        Kirkland Signature 科克蘭 西班牙初榨橄欖油 3公升    $499
# 43                       老舊金山原味拿鐵 20公克 X 125入    $659
# 44                   Barilla 百味來 義大利天使麵 500公克     $79
# 45                  Cemoi 82% 黑巧克力 100公克 X 6入    $269
# 46                      一芯一粒 CNS一等白米 3公斤 X 3入    $755
# 47                       湖池屋 和風海苔鹽厚切洋芋片 550公克    $198
#
#                                                    網址
# 0   https://www.costco.com.tw/Food/Drinks/Coffee-T...
# 1   https://www.costco.com.tw/Food/Snacks/Nuts-Chi...
# 2   https://www.costco.com.tw/Food/Frozen-Foods/Pr...
# 3   https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 4   https://www.costco.com.tw/Food/Drinks/Coffee-T...
# 5   https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 6   https://www.costco.com.tw/Food/Snacks/Cookies-...
# 7   https://www.costco.com.tw/Food/Snacks/Nuts-Chi...
# 8   https://www.costco.com.tw/Food/Drinks/Water-Be...
# 9   https://www.costco.com.tw/Food/Drinks/Powdered...
# 10  https://www.costco.com.tw/Lao-Xie-Zhen/Lao-Xie...
# 11  https://www.costco.com.tw/Food/Snacks/Nuts-Chi...
# 12  https://www.costco.com.tw/Food/Drinks/Powdered...
# 13  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 14  https://www.costco.com.tw/Food/Snacks/Chocolat...
# 15  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 16  https://www.costco.com.tw/Food/Snacks/Nuts-Chi...
# 17  https://www.costco.com.tw/Food/Drinks/Powdered...
# 18  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 19  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 20  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 21  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 22  https://www.costco.com.tw/Food/Drinks/Coffee-T...
# 23  https://www.costco.com.tw/Food/Frozen-Foods/Me...
# 24  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 25  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 26  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 27  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 28  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 29  https://www.costco.com.tw/Food/Snacks/Cookies-...
# 30  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 31  https://www.costco.com.tw/Food/Drinks/Coffee-T...
# 32  https://www.costco.com.tw/Food/Drinks/Powdered...
# 33  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 34  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 35  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 36  https://www.costco.com.tw/Food/Drinks/Powdered...
# 37  https://www.costco.com.tw/Food/Snacks/Cookies-...
# 38  https://www.costco.com.tw/Food/Snacks/Nuts-Chi...
# 39  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 40  https://www.costco.com.tw/Food/Drinks/Coffee-T...
# 41  https://www.costco.com.tw/Food/Snacks/Cookies-...
# 42  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 43  https://www.costco.com.tw/Food/Drinks/Coffee-T...
# 44  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 45  https://www.costco.com.tw/Food/Snacks/Chocolat...
# 46  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 47  https://www.costco.com.tw/Food/Snacks/Nuts-Chi...

# %%
#舊版
from pymongo import MongoClient
import pandas as pd
#連接MongoDB
client = MongoClient("mongodb+srv://test:test@cluster0.j7nzi.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
#指定資料庫
db = client.costco
#指定資料表
col=db.commodity
#直接從MongoDB查詢
name=col.distinct("商品名稱")
price=col.distinct("商品價格")
web=col.distinct("網址")
data=pd.DataFrame.from_dict({"商品名稱":name,"商品價格":price,"網址":web},orient='index')
type(data)
print(data)
# print(len(name))
# print(len(price))
# print(len(web))
# Out:
#                                                      0   \
# 商品名稱                           ARM & HAMMER 小蘇打粉 6.12公斤
# 商品價格                                             $1,379
# 網址    https://www.costco.com.tw/Food/Drinks/Coffee-T...
#
#                                                      1   \
# 商品名稱                  Alphamic 食物烹調專用紙 30公分 X 50公尺 X 2入
# 商品價格                                               $167
# 網址    https://www.costco.com.tw/Food/Drinks/Coffee-T...
#
#                                                      2   \
# 商品名稱                                Angie's 鹹甜爆米花 652公克
# 商品價格                                               $198
# 網址    https://www.costco.com.tw/Food/Drinks/Coffee-T...
#
#                                                      3   \
# 商品名稱                           Barilla 百味來 義大利天使麵 500公克
# 商品價格                                               $229
# 網址    https://www.costco.com.tw/Food/Drinks/Coffee-T...
#
#                                                      4   \
# 商品名稱                            Barilla 百味來 義大利粗麵 500公克
# 商品價格                                               $239
# 網址    https://www.costco.com.tw/Food/Drinks/Coffee-T...
#
#                                                      5   \
# 商品名稱                          Cemoi 82% 黑巧克力 100公克 X 6入
# 商品價格                                               $249
# 網址    https://www.costco.com.tw/Food/Drinks/Coffee-T...
#
#                                                      6   \
# 商品名稱                               Chosen Foods 酪梨油 1公升
# 商品價格                                               $269
# 網址    https://www.costco.com.tw/Food/Drinks/Powdered...
#
#                                                      7   \
# 商品名稱                           Evian 天然礦泉水 1500毫升 X 12入
# 商品價格                                               $295
# 網址    https://www.costco.com.tw/Food/Drinks/Powdered...
#
#                                                      8   \
# 商品名稱                             Godiva 歌帝梵 即溶可可粉 1.4公斤
# 商品價格                                               $299
# 網址    https://www.costco.com.tw/Food/Drinks/Powdered...
#
#                                                      9   ...  \
# 商品名稱                                     Kewpie 美奶滋 1公斤  ...
# 商品價格                                               $309  ...
# 網址    https://www.costco.com.tw/Food/Drinks/Powdered...  ...
#
#                                                      38  \
# 商品名稱                                 桂格減糖黑十穀 38公克 X 50入
# 商品價格                                               None
# 網址    https://www.costco.com.tw/Food/Snacks/Cookies-...
#
#                                                      39  \
# 商品名稱                                    桂格黃金麩片燕麥片 1.7公斤
# 商品價格                                               None
# 網址    https://www.costco.com.tw/Food/Snacks/Cookies-...
#
#                                                      40  \
# 商品名稱                             樂天 優格風味碳酸飲 250毫升 X 30入
# 商品價格                                               None
# 網址    https://www.costco.com.tw/Food/Snacks/Cookies-...
#
#                                                      41  \
# 商品名稱                                   櫻桃爺爺 南棗核桃糕 680公克
# 商品價格                                               None
# 網址    https://www.costco.com.tw/Food/Snacks/Nuts-Chi...
#
#                                                      42  \
# 商品名稱                               湖池屋 和風海苔鹽厚切洋芋片 550公克
# 商品價格                                               None
# 網址    https://www.costco.com.tw/Food/Snacks/Nuts-Chi...
#
#                                                      43  \
# 商品名稱                                老協珍 冷凍青木瓜排骨煲湯1730公克
# 商品價格                                               None
# 網址    https://www.costco.com.tw/Food/Snacks/Nuts-Chi...
#
#                                                      44  \
# 商品名稱                               老舊金山原味拿鐵 20公克 X 125入
# 商品價格                                               None
# 網址    https://www.costco.com.tw/Food/Snacks/Nuts-Chi...
#
#                                                      45  \
# 商品名稱                                        關山一級御用米 9公斤
# 商品價格                                               None
# 網址    https://www.costco.com.tw/Food/Snacks/Nuts-Chi...
#
#                                                      46  \
# 商品名稱                         雀巢 金牌冰萃濾袋研磨咖啡 10 公克 X 40 包
# 商品價格                                               None
# 網址    https://www.costco.com.tw/Food/Snacks/Nuts-Chi...
#
#                                                      47
# 商品名稱                                韓味不二 鹽烤海苔 5公克 X 36入
# 商品價格                                               None
# 網址    https://www.costco.com.tw/Lao-Xie-Zhen/Lao-Xie...
#
# [3 rows x 48 columns]
