# %%
from pymongo import MongoClient
import pandas as pd
#連接MongoDB
client = MongoClient("mongodb+srv://test:test@cluster0.j7nzi.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
#指定資料庫
db = client.costco
#指定資料表
col=db.FB_pythons
#直接從MongoDB查詢
post=col.distinct("FB內文")
# data=pd.DataFrame({"FB內文":post})
# print(data)
print(post)
#--------------------------------------------
#將FB內文進行斷詞
import jieba
word=[]
for i in post:
    a=jieba.cut(i)    
    word+=a
print(word)   
#--------------------------------------------
#統計每個字串出現次數
#把每個字串當成key去計算出現的次數(當成值)
dic_w={}
#判斷KEY(ele)是否在dic_w{}裡面
for ele in word:
    #如果KEY(ele)不在dic_w{}裡面,如果KEY沒出現過，就新增一筆KEY並讓值從1開始
    if ele not in dic_w:
        dic_w[ele]=1
    #如果KEY重複出現，值(AKA次數)就+1
    else:
        dic_w[ele]+=1
print(dic_w)
#--------------------------------------------
#調整顯示方式
#因為dic是無序的，所以要用.items來排序呼叫
for ele in dic_w.items():
#     print(ele[0],ele[1])
    #兩個字以上的，才會出現
    if len(ele[0])>=2:
        num=list()
        word=list()
        #因為經過.items的關係，變成(0,1)=(前面,後面)
#         print(ele[0],ele[1])
#--------------------------------------------
#要排序次數
import operator
#itemgetter是指出現該函數內第幾個的意思(從0開始數)
#.itemgetter()從0開始會變成依筆畫排列
sort_w=sorted(dic_w.items(),key=operator.itemgetter(1),reverse=True)
for ele in sort_w:
    num=list()
    word=list()
    for i in range(len(sort_w)):
        a=sort_w.pop()
        num.append(a[1])
        word.append(a[0])    
df_extract=pd.DataFrame({'num':num,'word':word})
print(df_extract)
# Out:
# ['#LaboLabo毛孔緊緻早晚安面膜組 #兩入589元前陣子才在賣場看到LaboLabo的洗面乳回歸今天來補貨家庭用品，看到同牌子的早晚安面膜也回來了！', '#卡士達可頌#芋泥可頌6個198 新品 好吃', '#地表最簡略的購物清單前陣子老媽傳了張截圖跟我說要買這些我一看，沒品牌沒品名只好從家裡最常用或折價的下手至於數字.....應該就是數量無誤…… 顯示更多', '#好市多肉鬆肉鬆蛋餅女兒睡前說早餐想吃蛋餅蛋餅裡放了她最愛的肉鬆可能是很久沒吃蛋餅了…… 顯示更多', '#好市多蝦子海苔蝦小飯糰最近找到一個沒什麼人煙的公園假日帶孩子去消耗體力寬敞的大公園孩子玩得很開心…… 顯示更多', '#好市多餐食 ', '#好市多鱸魚片 #黃耆山藥鱸魚湯平常都是煎魚片居多，最近疫情嚴重，很常喝蒜頭雞湯、藥膳魚湯食補，分享給大家做法。鱸魚片先用鹽醃一下先將藥材洗淨，放入水中將藥材煮出味道，湯會呈現琥珀色水滾後放入魚片，接著湯頭加鹽調味起…… 顯示更多', '#宮武讚岐日式炒麵#去骨清雞腿#好菇道雪白菇#黑木耳#鮮香菇…… 顯示更多', '#宮武讚岐豆皮烏龍麵麵不要煮太久！另外煮好再加入！自己愛吃的料全下就對了', '#消費經驗分享', '#澳洲羊梅花肉被搞得積非成是
�直接用來炒菜也覺得很方便，感覺可以燉可以炒真的頗萬用，被燒到很想買一台XD一直蹲等終於被我等到優惠，也上來分享分享', '叫老公幫我買個兩箱中筋麵粉搬回來這麼多', '台南店停車場撿到的已送至服務中心', '台南～今天有貨了到手', '各位男士們，如果你換了這款後…發現你尿尿時的泡泡怎麼變多了….', '商品情報連結 https://www.daybuy.tw/costco-20112Costco這款椰奶酥捲超好吃，現在賣場又有賣了~', '商品情報連結 https://www.daybuy.tw/costco-36473Costco再次到貨，RENNRAD16吋兒童腳踏車，兩種顏色，適合六歲以上兒童。', '在好市多大順店看到忍不住買來嚐鮮冰起來很像便宜油加太多的冰很像便宜的小美甜筒的口感如果要吃巧克力口味的甜筒我寧願吃杜老爺的', '在線掙扎中⋯⋯⋯⋯⋯', '夏天來點清爽的午餐家中越式春捲皮還有好市多買的Be Hot綜合生菜好市多買的扇貝跟蝦子就簡單的捲一捲做個涼皮蝦捲吧蘸…… 顯示更多', '外面藥房買不到感冒藥的，好市多還有喔￼', '大家換到了好市多可愛熊熊嗎？(門市現場新註冊線上購物會員可免費換一隻)', '大家有發現嗎？？？？Ariel洗衣精又做特價了，一組省180耶疫情在走，抗菌洗衣精真的也要懂用而且這次*沒有限購、沒有限購、沒有限購*同事都再揪團購了哈哈哈哈', '大推$449順口便宜實惠！', '大雷包……', '好事多買的黃玫瑰～真美，買回家插快10天還是美（不知道是那包買花送的小小包的秘密武器）10天後 掛吊讓它乾燥更美', '好吃嗎？辣度如何？在線等', '好奇有人知道這款洗髮露什麼時候會有特價嗎？  如果沒特價也沒關係，只是該回購了想碰碰運氣~    #補充一下自己的心得：  可能是因為我頭皮是中東油田，這罐洗起來才夠力  洗髮露一點點搓出來的泡泡就很多，洗感很清爽沒有悶悶殘留感  …… 顯示更多', '好市多堅果配德國豬腳，意外的對味耶，好吃', '好市多套餐#豬里肌 #日式炒麵 #彩椒', '好市多的#西瓜 一向都滿甜的 怎這次的西瓜有大半的部位軟軟地，怎會這樣，我是放在外面地上，是沒冰的問題嗎？切了一半，也丟了一半，也不甜，真無言，很想退，算了， ...
# ['#', 'LaboLabo', '毛孔', '緊', '緻', '早晚', '安', '面膜', '組', ' ', '#', '兩入', '589', '元前', '陣子', '才', '在', '賣場', '看到', 'LaboLabo', '的', '洗面乳', '回歸', '今天', '來', '補貨', '家庭用品', '，', '看到', '同', '牌子', '的', '早晚', '安', '面膜', '也', '回來', '了', '！', '#', '卡士', '達', '可頌', '#', '芋泥', '可頌', '6', '個', '198', ' ', '新品', ' ', '好吃', '#', '地表', '最', '簡略', '的', '購物', '清', '單前', '陣子', '老媽', '傳', '了', '張', '截圖', '跟', '我', '說', '要', '買', '這些', '我', '一看', '，', '沒', '品牌', '沒', '品名', '只好', '從家裡', '最', '常用', '或', '折價', '的', '下手', '至於', '數字', '.....', '應該', '就是', '數量', '無誤', '…', '…', ' ', '顯示', '更', '多', '#', '好市', '多', '肉', '鬆', '肉', '鬆', '蛋', '餅', '女', '兒', '睡', '前', '說', '早餐', '想', '吃', '蛋餅', '蛋餅', '裡放', '了', '她', '最愛的', '肉', '鬆', '可能', '是', '很', '久', '沒', '吃', '蛋餅', '了', '…', '…', ' ', '顯示', '更', '多', '#', '好市', '多', '蝦子', '海苔', '蝦小飯', '糰', '最近', '找到', '一個', '沒什麼', '人煙', '的', '公園', '假日', '帶', '孩子', '去', '消耗', '體力', '寬', '敞', '的', '大公', '園', '孩子', '玩得', '很', '開心', '…', '…', ' ', '顯示', '更', '多', '#', '好市', '多', '餐食', ' ', '#', '好市', '多', '鱸', '魚片', ' ', '#', '黃', '耆山藥', '鱸', '魚湯', '平常', '都', '是', '煎', '魚片', '居多', '，', '最近', '疫情', '嚴重', '，', '很', '常喝', '蒜頭', '雞湯', '、', '藥膳', '魚湯', '食補', '，', '分享', '給', '大家', '做法', '。', '鱸', '魚片', '先用', '鹽', '醃', '一下', '先將', '藥材', '洗淨', '，', '放入', '水中', '將藥材', '煮', '出', '味道', '，', '湯會', '呈現', '琥珀色', '水滾', '後', '放入', '魚片', '，', '接著', '湯頭', '加鹽', '調味起', '…', '…', ' ', '顯示', '更', '多', '#', '宮', '武', '讚', '岐', '日式', '炒', '麵', '#', '去', '骨', '清雞', '腿', '#', '好菇', '道', '雪白', '菇', '#', '黑木耳', '#', '鮮', '香菇', '…', '…', ' ', '顯示', '更', '多', '#', '宮', '武', '讚', '岐', '豆', '皮', '烏', '龍', '麵', '麵', '不要', '煮', '太久', '！', '另外', '煮', '好', '再', '加入', '！', '自己', '愛吃', '的', '料', '全下', '就', '對', '了', '#', '消費', '經驗', '分享', '#', '澳洲', '羊', '梅花', '肉', '被', '搞', '得積', '非成', '是', '都', '不', '知道', '自己', '煮', '的', '是', '什麼', '了', '#', '終於發', '囉', '到', '_', '開心', '#', '飛利浦氣', '炸鍋', 'HD9742', '#', '二次', '焗', '烤馬鈴', '薯燒', '#', '鬆', '餅', '粉', '雞', '蛋糕', '家中', '孩子', '遺傳到', '麵', '食控', '的', '基因', '，', '特愛吃', '雞', '蛋糕', '。', '幾樣', '簡單', '的', '材料', '，', '照著', '食譜', '在家', '也', '能', '輕', '鬆', '做出', '國民點', '心', '。', '100%', '純', '蜂蜜', '看', '大家', '都', '分享', '左邊', '這罐', '，', '右邊', '是', '新', '的', '嗎', '？', '評價', '如何', '呢', '？', '3M', ' ', '口罩', '請問', '有人', '買過', '這款', '口罩', '嗎', '？', '可以', '分享', '用', '的', '感受', '嗎', '？', '因其', '價格', '比', '一般', '口罩', '貴', '，', '謝謝', 'CNP', '綠蜂膠', ' ', '，', '也', '是', '因為', '社團', '有人', '介紹', '而', '購買', '此組', '本人', '是', '敏感', '肌膚', ' ', '臉', '容易', '泛紅', ' ', '，', '而用', '完', '的', '感想', '是', ' ', '不要', '擠過', '多', '在', '臉', '上', '，', '臉', '容易', '浮粉', '，', '適量', '即可', '！', '上妝前', '，', '可以', '提早', '10', '-', '20', '分鐘', '上', '這', '一瓶', '綠膠', '安瓶', '臉', '沒', '有', '像', '說', '的', '會光', '、', '會', '發亮', '但', '不', '容易', '出', '油', '（', '保水', '度', '還蠻夠', '）', '…', '…', ' ', '顯示', '更', '多', 'COSTCO', '早', '午餐', '~', '飲料', '：', '西雅圖', '大濾掛', '咖啡', '水果', '：', '芭樂', '堅果', '：', '杏仁', '豆主餐', '：', '小可', '頌', '+', '哈伐', '第', '切片', '乾酪', '+', '玉美履歷', '番茄', '+', '雞蛋', '+', '玉美履歷', '結球', '萵苣', '…', '…', ' ', '顯示', '更', '多', 'COSTCO', '買', '了', '阿舍', '乾', '麵', '的', '「', '客家', '板條', '」', '煮', '了', '半天', '橫豎', '看', '他', '都', '根本', '麵', '條啊後來', '看', '了', '外', '包裝', '真的', '是', '麵', '粉', '做', '的', '！', '客家人', '出來評', '評理', '！', '粄', '條', '應', '該', '是', '什', '麼', '做', '的', '？', '「', '板', '」', '不是', '「', '粄', '」', '為', '什麼', '￼', '跟', '我', '玩', '文字', '遊戲', '我書讀', '得', '少', '麻辣', '板條', '真的', '跟', '客家', '沒有', '什麼關', '係', '吧', '￼', '？', '…', '…', ' ', '顯示', '更', '多', '一次', '測試', '完', '所有', '口味', '，', '從', '左', '至', '右', '口感', '類似', '（', '金色', '）', '台灣', '經典', '啤酒', '，', '（', '藍綠色', '）', '台灣', '金牌', '啤酒', '，', '（', '天空', '藍', '）', '台灣', '啤酒', '！', '介紹', '完畢', '！', '一盒', '裡面', '有', '兩種', '口味', '耶', '！', '有灑', '糖粉', '的', '是', '卡士', '達', '餡', '+', '另', '一種', '是', '芋', '泥', '=', '各三個', '，', '198', '元', '！', '本來', '還想', '說', '，', '怎麼', '有', '的', '沒灑', '到', '糖粉', '！', '一直', '以來', '全家', '都', '很', '喜歡', '好市', '多', '這款', '香', '吉士', '我', '自己', '平常', '不太', '吃香', '吉士', '但', '￼', '這款',  ...
# {'#': 45, 'LaboLabo': 2, '毛孔': 1, '緊': 1, '緻': 1, '早晚': 2, '安': 2, '面膜': 3, '組': 6, ' ': 170, '兩入': 1, '589': 1, '元前': 1, '陣子': 2, '才': 14, '在': 40, '賣場': 6, '看到': 33, '的': 262, '洗面乳': 2, '回歸': 1, '今天': 18, '來': 38, '補貨': 4, '家庭用品': 1, '，': 362, '同': 1, '牌子': 3, '也': 51, '回來': 4, '了': 124, '！': 69, '卡士': 2, '達': 4, '可頌': 2, '芋泥': 1, '6': 4, '個': 5, '198': 2, '新品': 7, '好吃': 27, '地表': 1, '最': 8, '簡略': 1, '購物': 2, '清': 1, '單前': 1, '老媽': 2, '傳': 1, '張': 1, '截圖': 1, '跟': 21, '我': 76, '說': 19, '要': 25, '買': 63, '這些': 1, '一看': 2, '沒': 33, '品牌': 2, '品名': 1, '只好': 2, '從家�
因其': 1, '價格': 2, '比': 8, '一般': 3, '貴': 2, '謝謝': 13, 'CNP': 1, '綠蜂膠': 1, '因為': 10, '社團': 3, '介紹': 2, '而': 2, '購買': 3, '此組': 1, '本人': 1, '敏感': 1, '肌膚': 1, '臉': 4, '容易': 4, '泛紅': 1, '而用': 1, '完': 7, '感想': 1, '擠過': 1, '上': 21, '浮粉': 1, '適量': 1, '即可': 2, '上妝前': 1, '提早': 2, '10': 7, '-': 17, '20': 2, '分鐘': 6, '這': 18, '一瓶': 3, '綠膠': 1, '安瓶': 1, '有': 87, '像': 7, '會光': 1, '會': 24, '發亮': 1, '但': 19, '油': 5, '（': 26, '保水': 1, '度': 8, '還蠻夠': 1, '）': 27, 'COSTCO': 2, '早': 2, '午餐': 3, '~': 22, '飲料': 1, '：': 17, '西雅圖': 1, '大濾掛': 1, '咖啡': 6, '水果': 5, '芭樂': 3, '堅果': 2, '杏仁': 2, '豆主餐': 1, '小可': 1, '頌': 1, '+': 8, '哈伐': 1, '第': 1, '切片': 1, '乾酪': 2, '玉美履歷': 2, '番茄': 2, '雞蛋': 3, '結球': 2, '萵苣': 2, '阿舍': 1, '乾': 3, '「': 5, '客家': 2, '板條': 2, '」': 5, '半天': 1, '橫豎': 1, '他': 2, '根本': 1, '條啊後來': 1, '外': 2, '包裝': 4, '真的': 21, '做': 9, '客家人': 1, '出來評': 1, '評理': 1, '粄': 2, '條': 1, '應': 1, '該': 4, '什': 1, '麼': 1, '板': 1, '不是': 11, '為': 5, '￼': 37, '玩': 3, '文字': 1, '遊戲': 1, '我書讀': 1, '得': 3, '少': 1, '麻辣': 1, '沒有': 10, '什麼關': 1, '係': 3, '吧': 5, '一次': 8, '測試': 1, '所有': 1, '口味': 6, '從': 8, '左': 1, '至': 2, '右': 1, '口感': 3, '類似': 1, '金色': 1, '台灣': 3, '經典': 1, '啤酒': 3, '藍綠色': 1, '金牌': 1, '天空': 1, '藍': 1, '完畢': 1, '一盒': 4, '裡面': 5, '兩種': 2, '耶': 8, '有灑': 1, '糖粉': 2, '餡': 1, '另': 2, '一種': 1, '芋': 1, '泥': 1, '=': 2, '各三個': 1, '元': 10, '本來': 4, '還想': 1, '怎麼': 13, '沒灑': 1, '一直': 9, '以來': 2, '全家': 2, '喜歡': 11, '香': 4, '吉士': 3, '不太': 1, '吃香': 1, '香氣': 2, '很足': 1, '流行': 1, '果汁': 2, '馬': 6, '林糖': 1, '成份': 1, '只用': 1, '蛋白': 2, '和': 13, '糖': 2, '加上': 3, '打成': 1, '一開箱': 1, '瑕疵品': 1, '無法': 3, '感應': 1, '換了': 1, '電池': 1, '不行': 2, '害': 3, '興奮': 1, '試用': 1, '結果': 8, '一場': ...
#       num    word
# 0       1     升黑卡
# 1       1      打平
# 2       1  135000
# 3       1      多利
# 4       1      1%
# ...   ...     ...
# 2507   99       …
# 2508  124       了
# 2509  170
# 2510  262       的
# 2511  362       ，
#
# [2512 rows x 2 columns]

# %%
from pymongo import MongoClient
import pandas as pd
#連接MongoDB
client = MongoClient("mongodb+srv://test:test@cluster0.j7nzi.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
#指定資料庫
db = client.costco
#指定資料表
col=db.commodity2
#直接從MongoDB查詢
name=col.distinct("商品名稱")
price=col.distinct("商品價格")
web=col.distinct("網址")

df = pd.DataFrame(list(db.commodity2.find({},{ "_id": 0, "商品名稱": 1, "商品價格": 1, "網址": 1 })))
# print(pd.DataFrame.from_dict(df))
df
# Out:
#                                   商品名稱  \
# 0                Mackie's 經典牛奶冰淇淋 2 公升
# 1                            壽司派對盒 48入
# 2       Kirkland Signature 科克蘭 冷凍土魠魚切片
# 3            Kirkland Signature 科克蘭 小管
# 4                         北海道生干貝 S 1公斤
# 5        Kirkland Signature 科克蘭 薄鹽白腹鯖魚
# 6              DIXIE 冷飲紙杯 266毫升 X 360入
# 7       EVER FOREST 植物纖維圓盤 22公分 X 125入
# 8             DIXIE 高級免洗碗 354毫升 X 175入
# 9                      富統熱狗1KG SL60/52
# 10          五月花 妙用綿柔輕巧抽取衛生紙 130抽 X 36包
# 11     Faber-Castell 輝柏無毒石墨鉛筆48入 HB/2B
# 12  DOUBLE A A4專用影印紙80GSM/2500張/CIE152
# 13            MCCORMICK大蒜綜合香料調味粉637 公克
# 14                          TWS結晶冰糖2公斤
# 15                        TWS手工純黑糖2 公斤
# 16                          TABASCO辣椒醬
# 17  蜜蜂工坊台灣鮮採蜂蜜BEE TOUCHED TAIWAN HONEY
# 18                    非凡比整支玉米筍 2.95 公斤
# 19           PRIMA TASTE 新加坡叻沙225公克X 3
# 20    Kirkland Signature 科克蘭綜合貝果麵包 12入
# 21   Kirkland Signature 科克蘭 法國迷你可鬆 28入
# 22                             法國可鬆12入
# 23               斐濟天然深層礦泉水 500毫升 X 24瓶
# 24               EVIAN法國天然礦泉水500毫升X30入
# 25                     義美蜂蜜蛋糕400公克X2條入
# 26                  沛綠雅氣泡礦泉水250毫升X 35入
# 27                   聖沛黎洛氣泡礦泉水1公升X 12入
# 28                    可口可樂易開罐330毫升/32入
# 29               可口可樂ZERO易開罐330毫升X 32入
# 30                     雪碧易開罐330毫升X 32入
# 31                     伊藤園綠茶530毫升X 24入
# 32                     原萃日式綠茶575毫升/24入
# 33               Tree Top 果茶組合2公升X 4瓶裝
# 34                      麒麟午後奶茶1.5公升 4入
# 35                  動元素運動飲料 600毫升X 24入
# 36      Cavendish Farms 薯餅 20入 / 1.2公斤
# 37                          石安牧場溫泉蛋16入
# 38                   石安牧場香滷蛋白丁 100GX6入
# 39                      義美厚奶茶 946MLX3入
# 40                   傳貴有機無糖豆漿 900MLX3入
# 41                  福樂頂級多莓果優酪乳 1.7LX2入
# 42             福樂 頂級無加糖優酪乳 1.7公升 X 2瓶入
# 43              福樂草莓/ 蔓越莓低脂優格 180GX10入
# 44           GREEK GODS 蜂蜜希臘式優格 1.36KG
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
#FB貼文的斷詞
chart=pd.DataFrame(df_extract) 
#Costco商品列表
chart2=pd.DataFrame(df)

def fuzzy_merge(chart, chart2, key1, key2, threshold=20, limit=1):
    """
    :param df_1: the left table to join
    :param df_2: the right table to join
    :param key1: key column of the left table
    :param key2: key column of the right table
    :param threshold: how close the matches should be to return a match, based on Levenshtein distance
    :param limit: the amount of matches that will get returned, these are sorted high to low
    :return: dataframe with boths keys and matches
    """
    s = chart2[key2].tolist()
    m = chart[key1].apply(lambda x: process.extract(x, s, limit=limit))
    chart['matches'] = m
    m2 = chart['matches'].apply(lambda x: ', '.join([i[0] for i in x if i[1] >= threshold]))
    chart['matches'] = m2
    chart['merge_key'] = chart['matches']
    chart2['merge_key'] = chart2[key2]
    df = pd.merge(chart, chart2, how='left',on='merge_key')
    return df

df = fuzzy_merge(chart,chart2,'word','商品名稱',20)
final=df.drop(['matches','merge_key'],axis=1,inplace=True)

#資料清洗(讀取筆數要改成讀10筆(0~9))
final=df.dropna().sort_values(["num"],ascending=0,ignore_index=True).drop(["num","word"],axis=1)[0:10]
# print(final)
final
# Out:
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '］']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '［']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '』']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '『']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '..']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '🫣']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '&']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '--------------------------------']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.......']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '》']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '《']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.....']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '"']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '；']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '*']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '”']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '“']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '=']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '....']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ',']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ')']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '」']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '「']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '!']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '(']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '$']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '...']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '+']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '⁡']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ':']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '：']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '⋯']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '~']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '（']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '）']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '～']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '/']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '、']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '￼']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '。']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '#']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '！']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '？']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '…']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '，']
#                                商品名稱  \
# 0                福樂頂級多莓果優酪乳 1.7LX2入
# 1                 傳貴有機無糖豆漿 900MLX3入
# 2                           法國可鬆12入
# 3          MCCORMICK大蒜綜合香料調味粉637 公克
# 4    EVER FOREST 植物纖維圓盤 22公分 X 125入
# 5  Kirkland Signature 科克蘭綜合貝果麵包 12入
# 6                 傳貴有機無糖豆漿 900MLX3入
# 7        五月花 妙用綿柔輕巧抽取衛生紙 130抽 X 36包
# 8                      北海道生干貝 S 1公斤
# 9                    麒麟午後奶茶1.5公升 4入
#
#                                                   網址
# 0  https://www.costco.com.tw/Warehouse-Only/Food-...
# 1  https://www.costco.com.tw/Warehouse-Only/Food-...
# 2  https://www.costco.com.tw/Warehouse-Only/Food-...
# 3  https://www.costco.com.tw/Warehouse-Only/Food-...
# 4  https://www.costco.com.tw/Warehouse-Only/Hotel...
# 5  https://www.costco.com.tw/Warehouse-Only/Food-...
# 6  https://www.costco.com.tw/Warehouse-Only/Food-...
# 7  https://www.costco.com.tw/Warehouse-Only/Hotel...
# 8  https://www.costco.com.tw/Warehouse-Only/Food-...
# 9  https://www.costco.com.tw/Warehouse-Only/Food-...
